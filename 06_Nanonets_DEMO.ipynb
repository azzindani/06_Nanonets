# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/06_Nanonets_OCRs/blob/main/06_Nanonets_DEMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install gradio PyMuPDF locust beautifulsoup4 httpx pytest-cov
# !pip install -U transformers
# !pip install python-jose[cryptography] passlib[bcrypt]
# !pip install pytest-asyncio aiohttp
# !pip install pydantic[email]

# !git clone https://github.com/azzindani/06_Nanonets_OCRs.git
# %cd 06_Nanonets_OCRs

# %%
# !UI_SHARE=true python run_ui.py
# Out:
# ...
# NANONETS OCR - GRADIO UI
# ...
#
# [1/3] Initializing OCR engine...
# 2025-11-27 03:46:49.450223: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764215209.469267    2529 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764215209.475906    2529 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764215209.492729    2529 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
