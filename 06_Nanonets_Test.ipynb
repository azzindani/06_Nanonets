# %%
# ============================================
# NANONETS VL - COMPLETE TEST SUITE FOR KAGGLE
# ============================================

# ============================================
# CELL 1: SETUP & INSTALLATION
# ============================================

# %%
# %%capture
# !pip install gradio PyMuPDF locust beautifulsoup4 httpx pytest-cov
# !pip install -U transformers
# !pip install python-jose[cryptography] passlib[bcrypt]
# !pip install pytest-asyncio aiohttp

# !git clone https://github.com/azzindani/06_Nanonets.git
# %cd /kaggle/working/06_Nanonets

# %%
# ============================================
# CELL 2: SYNTAX CHECK
# ============================================
print("=" * 60)
print("SYNTAX CHECK")
print("=" * 60)
# !python -m py_compile config.py core/*.py api/*.py services/*.py ui/*.py
print("✓ Syntax check passed\n")
# Out:
# ============================================================
# SYNTAX CHECK
# ============================================================
# ✓ Syntax check passed

# %%
# ============================================
# CELL 3: CORE MODULE TESTS
# ============================================
print("=" * 60)
print("CORE MODULE TESTS")
print("=" * 60)
# !python -m core.test_complete_ocr
# !python -m core.schema_extractor
print("")
# Out:
# ============================================================
# CORE MODULE TESTS
# ============================================================
# ============================================================
# NANONETS VL - COMPLETE SYSTEM TEST
# ============================================================
# Started at: 2025-11-23 03:42:55
#
# [1/7] Testing Configuration...
#   ✓ Model: nanonets/Nanonets-OCR-s
#   ✓ Max tokens: 2048
#   ✓ Predefined fields: 52
#
# [2/7] Testing Output Parser...
#   ✓ Tables: 1
#   ✓ Equations: 1
#   ✓ Images: 1
#   ✓ Watermarks: 1
#   ✓ Checkboxes: 2
#
# [3/7] Testing Field Extractor...
#   ✓ Fields found: 5/6
#   ✓ Success rate: 83.3%
#   ✓ Company: Acme Corporation
#   ✓ Invoice: INV-2024-001
#
# [4/7] Testing Format Converter...
#   ✓ JSON output: 448 chars
#   ✓ XML output: 448 chars
#   ✓ HTML output: 459 chars
#
# [5/7] Testing Document Processor...
#   ✓ PDF validation: valid
#   ✓ XYZ validation: invalid (correct)
#   ✓ Image resize: (3000, 2000) -> (1536, 1024)
#
# [6/7] Testing Services...
#   ✓ Cache service: OK
#   ✓ Job queue: OK
#   ✓ Storage service: OK
#
# [7/7] Testing Validators...
#   ✓ API key validation: OK
#   ✓ URL validation: OK
#   ✓ Token validation: OK
#   ✓ Filename sanitization: OK
#
# ============================================================
# TEST SUMMARY
# ============================================================
#   Passed: 7/7
#   Failed: 0/7
#   Time: 2.47s
# ============================================================
# ✓ ALL TESTS PASSED
# ============================================================
# SCHEMA EXTRACTOR TEST
# ============================================================
#
# Extracted fields:
#   ✓ invoice_number: Invoice (confidence: 95%)
#   ✓ invoice_date: 2024-01-15 (confidence: 95%)
#   ✓ due_date: 2024-01-15 (confidence: 90%)
#   ✓ vendor_name: INVOICE (confidence: 50%)
#   ✓ total_amount: 1234.56 (confidence: 95%)
#   ✓ tax_amount: 98.76 (confidence: 95%)
#   ✓ currency: USD (confidence: 90%)
#
# Validation: 7/7 valid
# ============================================================

# %%
# ============================================
# CELL 4: SERVICES TESTS
# ============================================
print("=" * 60)
print("SERVICES TESTS")
print("=" * 60)
# !python -m services.test_services
# !python -m services.auth
# !python -m services.workflow
print("")
# Out:
# ============================================================
# SERVICES TESTS
# ============================================================
# ============================================================
# NANONETS VL - SERVICES TEST
# ============================================================
# Started at: 2025-11-23 03:42:58
#
# [1/3] Testing Cache Service...
#   ✓ Set/Get: OK
#   ✓ Exists check: OK
#   ✓ Delete: OK
#   ✓ OCR result caching: OK
#   ✓ Stats: memory
#
# [2/3] Testing Queue Service...
#   ✓ Enqueue: 2aec44d9..., dc4f2c1d...
#   ✓ Priority ordering: OK
#   ✓ Complete job: OK
#   ✓ Fail/retry: OK
#   ✓ Stats: 2 jobs
#
# [3/3] Testing Storage Service...
#   ✓ Save upload: 98c16d1743255f7f
#   ✓ Get upload: 33 bytes
#   ✓ Save result: OK
#   ✓ Get result: OK
#   ✓ Temp files: OK
#   ✓ Cleanup: OK
#
# ============================================================
# TEST SUMMARY
# ============================================================
#   Passed: 3/3
#   Failed: 0/3
#   Time: 0.02s
# ============================================================
# ✓ ALL TESTS PASSED
# (trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/passlib/handlers/bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# ============================================================
# AUTH SERVICE TEST
# ============================================================
# Password hash: 06998e1b933e06fb1a3b5c1cbbd40ce610fc8daaf86f1d08d0...
#   ✓ Password hashing works
# Access token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ1c...
#   ✓ Token creation works
#   ✓ Token verification works
# API key: nnt_YY8_Dcykfhf9jqE3...
#   ✓ API key generation works
# ============================================================
# ALL TESTS PASSED
# ============================================================
# ============================================================
# WORKFLOW ENGINE TEST
# ============================================================
# {"timestamp": "2025-11-23T03:42:59.735258Z", "level": "INFO", "logger": "nanonets.app", "message": "Created workflow", "module": "", "function": null, "line": 0, "workflow_id": "wf_38fd6906e4ee", "name": "Test Workflow", "steps": 1}
# Created workflow: wf_38fd6906e4ee
#   Steps: 1
# {"timestamp": "2025-11-23T03:42:59.735412Z", "level": "INFO", "logger": "nanonets.app", "message": "Starting workflow execution", "module": "", "function": null, "line": 0, "execution_id": "exec_d6e12ab080e6", "workflow_id": "wf_38fd6906e4ee"}
# {"timestamp": "2025-11-23T03:42:59.735507Z", "level": "INFO", "logger": "nanonets.app", "message": "Workflow execution completed", "module": "", "function": null, "line": 0, "execution_id": "exec_d6e12ab080e6", "status": "completed"}
# Execution: exec_d6e12ab080e6
#   Status: completed
#   ✓ Workflow engine working
# ============================================================

# %%
# ============================================
# CELL 5: UTILS TESTS
# ============================================
print("=" * 60)
print("UTILS TESTS")
print("=" * 60)
# !python -m utils.logger
print("")
# Out:
# ============================================================
# UTILS TESTS
# ============================================================
# ============================================================
# LOGGER MODULE TEST
# ============================================================
# {"timestamp": "2025-11-23T03:42:59.946716Z", "level": "INFO", "logger": "nanonets.app", "message": "Test message", "module": "", "function": null, "line": 0, "request_id": "req_75a8300dd5c74df8", "user_id": "user_123", "tenant_id": "tenant_456", "action": "test", "value": 42}
# {"timestamp": "2025-11-23T03:42:59.946777Z", "level": "INFO", "logger": "nanonets.ocr", "message": "OCR processing", "module": "", "function": null, "line": 0, "request_id": "req_75a8300dd5c74df8", "user_id": "user_123", "tenant_id": "tenant_456", "pages": 5, "confidence": 0.95}
# {"timestamp": "2025-11-23T03:42:59.946835Z", "level": "WARNING", "logger": "nanonets.api", "message": "Rate limit approaching", "module": "", "function": null, "line": 0, "request_id": "req_75a8300dd5c74df8", "user_id": "user_123", "tenant_id": "tenant_456", "remaining": 10}
# {"timestamp": "2025-11-23T03:42:59.946873Z", "level": "INFO", "logger": "nanonets.audit", "message": "Audit: document_uploaded", "module": "", "function": null, "line": 0, "request_id": "req_75a8300dd5c74df8", "user_id": "user_123", "tenant_id": "tenant_456", "action": "document_uploaded", "resource_type": "document", "resource_id": "doc_abc", "outcome": "success", "details": {"filename": "invoice.pdf", "file_size_bytes": 102400}}
# {"timestamp": "2025-11-23T03:42:59.946914Z", "level": "INFO", "logger": "nanonets.audit", "message": "Audit: document_processed", "module": "", "function": null, "line": 0, "request_id": "req_75a8300dd5c74df8", "user_id": "user_123", "tenant_id": "tenant_456", "action": "document_processed", "resource_type": "document", "resource_id": "doc_abc", "outcome": "success", "details": {"pages": 3, "processing_time_ms": 1250}}
#
#   ✓ Logger tests passed
# ============================================================

# %%
# ============================================
# CELL 6: API TESTS
# ============================================
print("=" * 60)
print("API TESTS")
print("=" * 60)
# !python -m api.test_api
print("")
# Out:
# ============================================================
# API TESTS
# ============================================================
# ============================================================
# NANONETS VL - API TEST
# ============================================================
# Started at: 2025-11-23 03:43:00
#
# [1/4] Testing Auth Middleware...
#   ✓ Key generation: sk_068b24ba5b418f1d4...
#   ✓ Key hashing: 3f13bc5202ac3c6e9d5d...
#   ✓ Signature creation: OK
#   ✓ Signature verification: OK
#
# [2/4] Testing Rate Limiter...
#   ✓ Sliding window: 5/5 allowed
#   ✓ Token bucket: rate limiting works
#
# [3/4] Testing API Schemas...
#   ✓ OCRRequest schema: OK
#   ✓ WebhookRequest schema: OK
#   ✓ HealthResponse schema: OK
#
# [4/4] Testing Webhook Manager...
#   ✓ Register webhook: a5cc461e...
#   ✓ Get webhook: OK
#   ✓ List webhooks: 1 found
#   ✓ Unregister: OK
#
# ============================================================
# TEST SUMMARY
# ============================================================
#   Passed: 4/4
#   Failed: 0/4
#   Time: 0.49s
# ============================================================
# ✓ ALL TESTS PASSED

# %%
# ============================================
# CELL 7: ASSET-BASED TESTS
# ============================================
print("=" * 60)
print("ASSET-BASED TESTS")
print("=" * 60)
# !python -m tests.test_with_assets
print("")
# Out:
# ============================================================
# ASSET-BASED TESTS
# ============================================================
# ============================================================
# NANONETS VL - ASSET-BASED TESTS
# ============================================================
# Started at: 2025-11-23 03:43:00
#
# Test assets found: 0
#   (Will use synthetic documents)
#
#   To add assets, place files in: /kaggle/working/06_Nanonets/tests/fixtures
#
# [1/5] Testing Multi-Page Document Support...
#   ⚠ No PDF available (install reportlab for synthetic)
#
# [2/5] Testing Image Processing...
#   Created synthetic image: synthetic_document.png
#   ✓ Original: (800, 600)
#   ✓ Processed: (800, 600)
#
# [3/5] Testing Bounding Box Visualization...
#   ✓ Drew 3 bounding boxes
#   ✓ Saved to: /kaggle/working/06_Nanonets/tests/fixtures/outputs/bbox_visualization.png
#
# [4/5] Testing Field Extraction...
#   ✓ Fields found: 6/52
#   ✓ Success rate: 11.5%
#     - Invoice Number: INV-2024-001
#
# [5/5] Testing Output Formats...
#   ✓ JSON: 863 chars
#   ✓ XML: 1014 chars
#   ✓ HTML: 671 chars
#   ✓ CSV: 38 chars
#   ✓ Outputs saved to: /kaggle/working/06_Nanonets/tests/fixtures/outputs
#
# ============================================================
# TEST SUMMARY
# ============================================================
#   Passed: 5/5
#   Failed: 0/5
#   Time: 0.77s
# ============================================================
# ✓ ALL TESTS PASSED

# %%
# ============================================
# CELL 8: UNIT TESTS (PYTEST)
# ============================================
print("=" * 60)
print("UNIT TESTS")
print("=" * 60)
# !pytest tests/unit/test_document_classifier.py -v --tb=short
# !pytest tests/unit/test_language_support.py -v --tb=short
# !pytest tests/unit/test_semantic_extractor.py -v --tb=short
# !pytest tests/unit/test_structured_output.py -v --tb=short
print("")
# Out:
# ============================================================
# UNIT TESTS
# ============================================================
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/06_Nanonets
# configfile: pytest.ini
# plugins: asyncio-1.3.0, locust-2.42.5, cov-7.0.0, anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 12 items
#
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_invoice PASSED [  8%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_receipt PASSED [ 16%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_contract PASSED [ 25%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_medical PASSED [ 33%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_bank_statement PASSED [ 41%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_unknown PASSED [ 50%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_empty_text PASSED [ 58%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_with_routing PASSED [ 66%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_get_supported_types PASSED [ 75%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_all_scores_populated PASSED [ 83%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_singleton_instance PASSED [ 91%]
# tests/unit/test_document_classifier.py::TestDocumentType::test_all_document_types PASSED [100%]
#
# ============================== 12 passed in 0.06s ==============================
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/06_Nanonets
# configfile: pytest.ini
# plugins: asyncio-1.3.0, locust-2.42.5, cov-7.0.0, anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 22 items
#
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_english PASSED [  4%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_spanish PASSED [  9%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_french PASSED [ 13%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_german PASSED [ 18%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_russian PASSED [ 22%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_chinese PASSED [ 27%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_japanese PASSED [ 31%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_korean PASSED [ 36%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_arabic PASSED [ 40%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_empty_text PASSED [ 45%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_whitespace_only PASSED [ 50%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_all_scores_populated PASSED [ 54%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_multilingual_detection PASSED [ 59%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_get_supported_languages PASSED [ 63%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_singleton_instance PASSED [ 68%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_process_english_document PASSED [ 72%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_process_spanish_document PASSED [ 77%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_get_field_pattern PASSED [ 81%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_get_field_pattern_unknown PASSED [ 86%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_singleton_instance PASSED [ 90%]
# tests/unit/test_language_support.py::TestLanguageEnum::test_all_languages_defined PASSED [ 95%]
# tests/unit/test_language_support.py::TestLanguageEnum::test_language_count PASSED [100%]
#
# ============================== 22 passed in 0.09s ==============================
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/06_Nanonets
# configfile: pytest.ini
# plugins: asyncio-1.3.0, locust-2.42.5, cov-7.0.0, anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 16 items
#
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_basic_entities PASSED [  6%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_payment_info PASSED [ 12%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_contact_info PASSED [ 18%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_with_queries PASSED [ 25%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_dates PASSED [ 31%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_monetary_values PASSED [ 37%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_email_addresses PASSED [ 43%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_phone_numbers PASSED [ 50%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_generate_summary PASSED [ 56%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_key_points PASSED [ 62%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_with_schema PASSED [ 68%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_empty_text PASSED [ 75%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_semantic_field_properties PASSED [ 81%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_organizations PASSED [ 87%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_singleton_instance PASSED [ 93%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_entity_confidence_scores PASSED [100%]
#
# ============================== 16 passed in 0.06s ==============================
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/06_Nanonets
# configfile: pytest.ini
# plugins: asyncio-1.3.0, locust-2.42.5, cov-7.0.0, anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 13 items
#
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_process_invoice PASSED [  7%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_extract_invoice_fields PASSED [ 15%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_extract_receipt_fields PASSED [ 23%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_entity_extraction PASSED [ 30%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_language_detection PASSED [ 38%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_line_item_parsing PASSED [ 46%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_empty_text PASSED [ 53%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_nested_field_structure PASSED [ 61%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_raw_data_included PASSED [ 69%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_singleton_instance PASSED [ 76%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_convenience_function PASSED [ 84%]
# tests/unit/test_structured_output.py::TestLineItemParsing::test_parse_with_sku PASSED [ 92%]
# tests/unit/test_structured_output.py::TestLineItemParsing::test_empty_table PASSED [100%]
#
# ============================== 13 passed in 0.63s ==============================

# %%
# ============================================
# CELL 9: INTEGRATION TESTS (PYTEST)
# ============================================
print("=" * 60)
print("INTEGRATION TESTS")
print("=" * 60)
# !pytest tests/integration/test_api_integration.py -v --tb=short
# !pytest tests/integration/test_api_v2.py -v --tb=short
print("")
# Out:
# ============================================================
# INTEGRATION TESTS
# ============================================================
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/06_Nanonets
# configfile: pytest.ini
# plugins: asyncio-1.3.0, locust-2.42.5, cov-7.0.0, anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 14 items
#
# tests/integration/test_api_integration.py::TestHealthEndpoints::test_health_check PASSED [  7%]
# tests/integration/test_api_integration.py::TestHealthEndpoints::test_ready_check PASSED [ 14%]
# tests/integration/test_api_integration.py::TestOCREndpoints::test_process_image_endpoint PASSED [ 21%]
# tests/integration/test_api_integration.py::TestOCREndpoints::test_process_without_image PASSED [ 28%]
# tests/integration/test_api_integration.py::TestOCREndpoints::test_batch_processing PASSED [ 35%]
# tests/integration/test_api_integration.py::TestDocumentProcessing::test_document_classification_flow PASSED [ 42%]
# tests/integration/test_api_integration.py::TestDocumentProcessing::test_semantic_extraction_flow PASSED [ 50%]
# tests/integration/test_api_integration.py::TestEndToEndWorkflow::test_ocr_pipeline_components PASSED [ 57%]
# tests/integration/test_api_integration.py::TestEndToEndWorkflow::test_classification_to_extraction_flow PASSED [ 64%]
# tests/integration/test_api_integration.py::TestEndToEndWorkflow::test_multilingual_processing_flow PASSED [ 71%]
# tests/integration/test_api_integration.py::TestErrorHandling::test_invalid_endpoint PASSED [ 78%]
# tests/integration/test_api_integration.py::TestErrorHandling::test_invalid_method PASSED [ 85%]
# tests/integration/test_api_integration.py::TestErrorHandling::test_malformed_json PASSED [ 92%]
# tests/integration/test_api_integration.py::TestConcurrency::test_multiple_health_checks PASSED [100%]
#
# ============================= 14 passed in 35.76s ==============================
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/06_Nanonets
# configfile: pytest.ini
# plugins: asyncio-1.3.0, locust-2.42.5, cov-7.0.0, anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 20 items
#
# tests/integration/test_api_v2.py::TestAPIv2Endpoint::test_v2_ocr_returns_structured_output PASSED [  5%]
# tests/integration/test_api_v2.py::TestAPIv2Endpoint::test_v2_ocr_invalid_file_type PASSED [ 10%]
# tests/integration/test_api_v2.py::TestAPIv2Endpoint::test_v2_ocr_missing_file PASSED [ 15%]
# tests/integration/test_api_v2.py::TestClassifyEndpoint::test_classify_with_file PASSED [ 20%]
# tests/integration/test_api_v2.py::TestClassifyEndpoint::test_classify_with_text PASSED [ 25%]
# tests/integration/test_api_v2.py::TestClassifyEndpoint::test_classify_no_input PASSED [ 30%]
# tests/integration/test_api_v2.py::TestDetectLanguageEndpoint::test_detect_language_english PASSED [ 35%]
# tests/integration/test_api_v2.py::TestDetectLanguageEndpoint::test_detect_language_spanish PASSED [ 40%]
# tests/integration/test_api_v2.py::TestDetectLanguageEndpoint::test_detect_language_no_input PASSED [ 45%]
# tests/integration/test_api_v2.py::TestExtractEntitiesEndpoint::test_extract_entities_with_text PASSED [ 50%]
# tests/integration/test_api_v2.py::TestExtractEntitiesEndpoint::test_extract_entities_no_input PASSED [ 55%]
# tests/integration/test_api_v2.py::TestStructuredEndpoint::test_structured_output PASSED [ 60%]
# tests/integration/test_api_v2.py::TestRateLimiting::test_rate_limit_headers PASSED [ 65%]
# tests/integration/test_api_v2.py::TestRateLimiting::test_health_endpoint_not_rate_limited PASSED [ 70%]
# tests/integration/test_api_v2.py::TestAPIKeyAuthentication::test_endpoints_work_with_api_key PASSED [ 75%]
# tests/integration/test_api_v2.py::TestAPIKeyAuthentication::test_classify_with_api_key PASSED [ 80%]
# tests/integration/test_api_v2.py::TestErrorHandling::test_invalid_endpoint PASSED [ 85%]
# tests/integration/test_api_v2.py::TestErrorHandling::test_method_not_allowed PASSED [ 90%]
# tests/integration/test_api_v2.py::TestErrorHandling::test_unsupported_file_type_v2 PASSED [ 95%]
# tests/integration/test_api_v2.py::TestPersonEntityFiltering::test_filters_document_labels PASSED [100%]
#
# ============================= 20 passed in 53.67s ==============================

# %%
# ============================================
# CELL 10: FULL PYTEST SUITE WITH COVERAGE
# ============================================
print("=" * 60)
print("FULL TEST SUITE WITH COVERAGE")
print("=" * 60)
# !pytest tests/ -v --cov=core --cov=api --cov=services --cov-report=term-missing
print("")
# Out:
# ============================================================
# FULL TEST SUITE WITH COVERAGE
# ============================================================
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/06_Nanonets
# configfile: pytest.ini
# plugins: asyncio-1.3.0, locust-2.42.5, cov-7.0.0, anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# asyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 167 items
#
# tests/integration/test_api_endpoints.py::TestHealthEndpoints::test_health_check PASSED [  0%]
# tests/integration/test_api_endpoints.py::TestHealthEndpoints::test_models_endpoint PASSED [  1%]
# tests/integration/test_api_endpoints.py::TestRootEndpoint::test_root PASSED [  1%]
# tests/integration/test_api_endpoints.py::TestWebhookEndpoints::test_register_webhook PASSED [  2%]
# tests/integration/test_api_endpoints.py::TestWebhookEndpoints::test_list_webhooks PASSED [  2%]
# tests/integration/test_api_endpoints.py::TestWebhookEndpoints::test_get_webhook_not_found PASSED [  3%]
# tests/integration/test_api_endpoints.py::TestWebhookEndpoints::test_unregister_webhook PASSED [  4%]
# tests/integration/test_api_endpoints.py::TestRateLimiting::test_rate_limit_headers PASSED [  4%]
# tests/integration/test_api_endpoints.py::TestErrorHandling::test_404_not_found PASSED [  5%]
# tests/integration/test_api_endpoints.py::TestErrorHandling::test_invalid_webhook_data PASSED [  5%]
# tests/integration/test_api_integration.py::TestHealthEndpoints::test_health_check PASSED [  6%]
# tests/integration/test_api_integration.py::TestHealthEndpoints::test_ready_check PASSED [  7%]
# tests/integration/test_api_integration.py::TestOCREndpoints::test_process_image_endpoint PASSED [  7%]
# tests/integration/test_api_integration.py::TestOCREndpoints::test_process_without_image PASSED [  8%]
# tests/integration/test_api_integration.py::TestOCREndpoints::test_batch_processing PASSED [  8%]
# tests/integration/test_api_integration.py::TestDocumentProcessing::test_document_classification_flow PASSED [  9%]
# tests/integration/test_api_integration.py::TestDocumentProcessing::test_semantic_extraction_flow PASSED [ 10%]
# tests/integration/test_api_integration.py::TestEndToEndWorkflow::test_ocr_pipeline_components PASSED [ 10%]
# tests/integration/test_api_integration.py::TestEndToEndWorkflow::test_classification_to_extraction_flow PASSED [ 11%]
# tests/integration/test_api_integration.py::TestEndToEndWorkflow::test_multilingual_processing_flow PASSED [ 11%]
# tests/integration/test_api_integration.py::TestErrorHandling::test_invalid_endpoint PASSED [ 12%]
# tests/integration/test_api_integration.py::TestErrorHandling::test_invalid_method PASSED [ 13%]
# tests/integration/test_api_integration.py::TestErrorHandling::test_malformed_json PASSED [ 13%]
# tests/integration/test_api_integration.py::TestConcurrency::test_multiple_health_checks PASSED [ 14%]
# tests/integration/test_api_v2.py::TestAPIv2Endpoint::test_v2_ocr_returns_structured_output PASSED [ 14%]
# tests/integration/test_api_v2.py::TestAPIv2Endpoint::test_v2_ocr_invalid_file_type PASSED [ 15%]
# tests/integration/test_api_v2.py::TestAPIv2Endpoint::test_v2_ocr_missing_file PASSED [ 16%]
# tests/integration/test_api_v2.py::TestClassifyEndpoint::test_classify_with_file PASSED [ 16%]
# tests/integration/test_api_v2.py::TestClassifyEndpoint::test_classify_with_text PASSED [ 17%]
# tests/integration/test_api_v2.py::TestClassifyEndpoint::test_classify_no_input PASSED [ 17%]
# tests/integration/test_api_v2.py::TestDetectLanguageEndpoint::test_detect_language_english PASSED [ 18%]
# tests/integration/test_api_v2.py::TestDetectLanguageEndpoint::test_detect_language_spanish PASSED [ 19%]
# tests/integration/test_api_v2.py::TestDetectLanguageEndpoint::test_detect_language_no_input PASSED [ 19%]
# tests/integration/test_api_v2.py::TestExtractEntitiesEndpoint::test_extract_entities_with_text PASSED [ 20%]
# tests/integration/test_api_v2.py::TestExtractEntitiesEndpoint::test_extract_entities_no_input PASSED [ 20%]
# tests/integration/test_api_v2.py::TestStructuredEndpoint::test_structured_output PASSED [ 21%]
# tests/integration/test_api_v2.py::TestRateLimiting::test_rate_limit_headers PASSED [ 22%]
# tests/integration/test_api_v2.py::TestRateLimiting::test_health_endpoint_not_rate_limited PASSED [ 22%]
# tests/integration/test_api_v2.py::TestAPIKeyAuthentication::test_endpoints_work_with_api_key PASSED [ 23%]
# tests/integration/test_api_v2.py::TestAPIKeyAuthentication::test_classify_with_api_key PASSED [ 23%]
# tests/integration/test_api_v2.py::TestErrorHandling::test_invalid_endpoint PASSED [ 24%]
# tests/integration/test_api_v2.py::TestErrorHandling::test_method_not_allowed PASSED [ 25%]
# tests/integration/test_api_v2.py::TestErrorHandling::test_unsupported_file_type_v2 PASSED [ 25%]
# tests/integration/test_api_v2.py::TestPersonEntityFiltering::test_filters_document_labels PASSED [ 26%]
# tests/integration/test_full_pipeline.py::TestFullPipeline::test_document_processor_image PASSED [ 26%]
# tests/integration/test_full_pipeline.py::TestFullPipeline::test_document_processor_pdf PASSED [ 27%]
# tests/integration/test_full_pipeline.py::TestFullPipeline::test_output_parser_with_sample_text PASSED [ 28%]
# tests/integration/test_full_pipeline.py::TestFullPipeline::test_field_extractor_with_invoice PASSED [ 28%]
# tests/integration/test_full_pipeline.py::TestFullPipeline::test_format_converter_outputs PASSED [ 29%]
# tests/integration/test_full_pipeline.py::TestFullPipeline::test_pipeline_end_to_end PASSED [ 29%]
# tests/integration/test_full_pipeline.py::TestCacheIntegration::test_cache_ocr_result PASSED [ 30%]
# tests/integration/test_full_pipeline.py::TestStorageIntegration::test_storage_workflow PASSED [ 31%]
# tests/test_with_assets.py::test_document_processor_multipage PASSED      [ 31%]
# tests/test_with_assets.py::test_image_processing PASSED                  [ 32%]
# tests/test_with_assets.py::test_bounding_box_visualization PASSED        [ 32%]
# tests/test_with_assets.py::test_field_extraction_on_assets PASSED        [ 33%]
# tests/test_with_assets.py::test_format_outputs PASSED                    [ 34%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_invoice PASSED [ 34%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_receipt PASSED [ 35%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_contract PASSED [ 35%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_medical PASSED [ 36%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_bank_statement PASSED [ 37%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_unknown PASSED [ 37%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_empty_text PASSED [ 38%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_classify_with_routing PASSED [ 38%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_get_supported_types PASSED [ 39%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_all_scores_populated PASSED [ 40%]
# tests/unit/test_document_classifier.py::TestDocumentClassifier::test_singleton_instance PASSED [ 40%]
# tests/unit/test_document_classifier.py::TestDocumentType::test_all_document_types PASSED [ 41%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_validate_nonexistent_file PASSED [ 41%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_validate_unsupported_extension PASSED [ 42%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_validate_pdf_extension PASSED [ 43%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_validate_image_extension PASSED [ 43%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_preprocess_image_no_resize_needed PASSED [ 44%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_preprocess_image_resize_width PASSED [ 44%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_preprocess_image_resize_height PASSED [ 45%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_get_file_metadata_image PASSED [ 46%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_get_file_metadata_pdf PASSED [ 46%]
# tests/unit/test_document_processor.py::TestDocumentProcessor::test_extract_pdf_pages PASSED [ 47%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_extract_invoice_number PASSED [ 47%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_extract_multiple_fields PASSED [ 48%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_extract_missing_field PASSED [ 49%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_custom_fields PASSED [ 49%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_confidence_scores PASSED [ 50%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_get_statistics PASSED [ 50%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_to_dict PASSED [ 51%]
# tests/unit/test_field_extractor.py::TestFieldExtractor::test_case_insensitive_extraction PASSED [ 52%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_english PASSED [ 52%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_spanish PASSED [ 53%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_french PASSED [ 53%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_german PASSED [ 54%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_russian PASSED [ 55%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_chinese PASSED [ 55%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_japanese PASSED [ 56%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_korean PASSED [ 56%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_arabic PASSED [ 57%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_empty_text PASSED [ 58%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_detect_whitespace_only PASSED [ 58%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_all_scores_populated PASSED [ 59%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_multilingual_detection PASSED [ 59%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_get_supported_languages PASSED [ 60%]
# tests/unit/test_language_support.py::TestLanguageDetector::test_singleton_instance PASSED [ 61%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_process_english_document PASSED [ 61%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_process_spanish_document PASSED [ 62%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_get_field_pattern PASSED [ 62%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_get_field_pattern_unknown PASSED [ 63%]
# tests/unit/test_language_support.py::TestMultiLanguageProcessor::test_singleton_instance PASSED [ 64%]
# tests/unit/test_language_support.py::TestLanguageEnum::test_all_languages_defined PASSED [ 64%]
# tests/unit/test_language_support.py::TestLanguageEnum::test_language_count PASSED [ 65%]
# tests/unit/test_output_parser.py::TestOutputParser::test_parse_empty_text PASSED [ 65%]
# tests/unit/test_output_parser.py::TestOutputParser::test_parse_single_page PASSED [ 66%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_tables PASSED [ 67%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_no_tables PASSED [ 67%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_equations_inline PASSED [ 68%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_equations_display PASSED [ 68%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_images PASSED [ 69%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_watermarks PASSED [ 70%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_page_numbers PASSED [ 70%]
# tests/unit/test_output_parser.py::TestOutputParser::test_extract_checkboxes PASSED [ 71%]
# tests/unit/test_output_parser.py::TestOutputParser::test_to_dict PASSED  [ 71%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_basic_entities PASSED [ 72%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_payment_info PASSED [ 73%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_contact_info PASSED [ 73%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_with_queries PASSED [ 74%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_dates PASSED [ 74%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_monetary_values PASSED [ 75%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_email_addresses PASSED [ 76%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_phone_numbers PASSED [ 76%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_generate_summary PASSED [ 77%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_key_points PASSED [ 77%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_with_schema PASSED [ 78%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_empty_text PASSED [ 79%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_semantic_field_properties PASSED [ 79%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_extract_organizations PASSED [ 80%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_singleton_instance PASSED [ 80%]
# tests/unit/test_semantic_extractor.py::TestSemanticExtractor::test_entity_confidence_scores PASSED [ 81%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_process_invoice PASSED [ 82%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_extract_invoice_fields PASSED [ 82%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_extract_receipt_fields PASSED [ 83%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_entity_extraction PASSED [ 83%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_language_detection PASSED [ 84%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_line_item_parsing PASSED [ 85%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_empty_text PASSED [ 85%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_nested_field_structure PASSED [ 86%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_raw_data_included PASSED [ 86%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_singleton_instance PASSED [ 87%]
# tests/unit/test_structured_output.py::TestStructuredOutputProcessor::test_convenience_function PASSED [ 88%]
# tests/unit/test_structured_output.py::TestLineItemParsing::test_parse_with_sku PASSED [ 88%]
# tests/unit/test_structured_output.py::TestLineItemParsing::test_empty_table PASSED [ 89%]
# tests/unit/test_validators.py::TestValidators::test_validate_file_path_empty PASSED [ 89%]
# tests/unit/test_validators.py::TestValidators::test_validate_file_path_nonexistent PASSED [ 90%]
# tests/unit/test_validators.py::TestValidators::test_validate_file_extension_pdf PASSED [ 91%]
# tests/unit/test_validators.py::TestValidators::test_validate_file_extension_unsupported PASSED [ 91%]
# tests/unit/test_validators.py::TestValidators::test_validate_api_key_empty PASSED [ 92%]
# tests/unit/test_validators.py::TestValidators::test_validate_api_key_short PASSED [ 92%]
# tests/unit/test_validators.py::TestValidators::test_validate_api_key_valid PASSED [ 93%]
# tests/unit/test_validators.py::TestValidators::test_validate_url_empty PASSED [ 94%]
# tests/unit/test_validators.py::TestValidators::test_validate_url_valid PASSED [ 94%]
# tests/unit/test_validators.py::TestValidators::test_validate_url_invalid PASSED [ 95%]
# tests/unit/test_validators.py::TestValidators::test_validate_max_tokens_too_low PASSED [ 95%]
# tests/unit/test_validators.py::TestValidators::test_validate_max_tokens_too_high PASSED [ 96%]
# tests/unit/test_validators.py::TestValidators::test_validate_max_tokens_valid PASSED [ 97%]
# tests/unit/test_validators.py::TestValidators::test_validate_image_size_too_small PASSED [ 97%]
# tests/unit/test_validators.py::TestValidators::test_validate_image_size_too_large PASSED [ 98%]
# tests/unit/test_validators.py::TestValidators::test_validate_image_size_valid PASSED [ 98%]
# tests/unit/test_validators.py::TestValidators::test_sanitize_filename_path_traversal PASSED [ 99%]
# tests/unit/test_validators.py::TestValidators::test_sanitize_filename_preserves_name PASSED [100%]
#
# ================================ tests coverage ================================
# _______________ coverage: platform linux, python 3.11.13-final-0 _______________
#
# Name                                 Stmts   Miss  Cover   Missing
# ------------------------------------------------------------------
# api/__init__.py                          0      0   100%
# api/middleware/__init__.py               0      0   100%
# api/middleware/auth.py                  67     42    37%   21, 27, 43-50, 63, 76-78, 92, 111-112, 125-132, 136-140, 144-148, 156-179
# api/middleware/rate_limit.py            97     39    60%   15, 35-38, 50-63, 67-69, 110-112, 149, 163, 180-191, 214, 226-239
# api/routes/__init__.py                   0      0   100%
# api/routes/auth.py                     105     55    48%   66-91, 107-133, 141-172, 180-204, 219, 236-245, 254-262
# api/routes/health.py                    72     20    72%   77, 86-137, 145-147, 193-194, 219-220, 225-227
# api/routes/ocr.py                      239    130    46%   57-198, 209, 291-305, 345-359, 429, 455-456, 486, 507, 515-516, 541-613
# api/routes/webhook.py                   95     42    56%   60, 72, 88-153, 157-162, 203, 234, 248-250, 262-272
# api/schemas/__init__.py                  0      0   100%
# api/schemas/request.py                  15      0   100%
# api/schemas/response.py                 37      0   100%
# api/server.py                           47     11    77%   69, 99-100, 109-117
# api/test_api.py                        116    116     0%   6-200
# core/__init__.py                         0      0   100%
# core/document_classifier.py             65      1    98%   242
# core/document_processor.py             108     19    82%   159, 197, 214-239
# core/field_extractor.py                 78     24    69%   50-51, 67, 148, 190-228
# core/format_converter.py               101     41    59%   68-70, 74-76, 80-82, 115, 194-201, 213-223, 227-264
# core/format_support.py                 142    142     0%   4-247
# core/language_support.py               139      5    96%   262, 264, 268, 270, 274
# core/ocr_engine.py                     107     29    73%   61-64, 122-127, 141-150, 229-230, 260-278
# core/output_parser.py                  112     23    79%   121-122, 150-152, 256-293
# core/schema_extractor.py               136    136     0%   4-378
# core/semantic_extractor.py             109      1    99%   152
# core/structured_output.py              123      1    99%   329
# core/test_complete_ocr.py              196    196     0%   6-323
# services/__init__.py                     0      0   100%
# services/auth.py                       119     69    42%   16-18, 25, 63-66, 70-73, 84-101, 105-117, 127-130, 138-146, 150-154, 171-176, 181, 186, 194-231
# services/cache.py                      130     76    42%   42, 46-54, 87-92, 100-102, 119-124, 144-153, 157-166, 175-186, 190-203, 245-269
# services/celery_app.py                   8      8     0%   4-69
# services/notifications/__init__.py       4      4     0%   4-8
# services/notifications/base.py          38     38     0%   4-95
# services/notifications/email.py         67     67     0%   4-189
# services/notifications/slack.py         47     47     0%   4-128
# services/queue.py                      165    165     0%   4-309
# services/s3_storage.py                  89     89     0%   4-271
# services/storage.py                    118     40    66%   130, 147, 164, 181, 193-195, 204-209, 213-226, 246-280
# services/tasks.py                       82     82     0%   4-255
# services/test_services.py              131    131     0%   6-208
# services/workflow.py                   162    162     0%   4-410
# ------------------------------------------------------------------
# TOTAL                                 3466   2051    41%
# ============================= 167 passed in 36.46s =============================

# %%
# ============================================
# CELL 11: BENCHMARK TEST
# ============================================
print("=" * 60)
print("BENCHMARK TEST")
print("=" * 60)
# !python tests/performance/benchmark.py
print("")
# Out:
# ============================================================
# BENCHMARK TEST
# ============================================================
#
# ============================================================
# NANONETS OCR BENCHMARK
# ============================================================
# Iterations: 50
# Image size: 512x512
# ============================================================
#
# Running: Image Loading...
#   Mean: 0.02ms | P95: 0.04ms | Throughput: 42356.73/sec
# Running: Output Parsing...
#   Mean: 12.71ms | P95: 13.96ms | Throughput: 78.71/sec
# Running: Field Extraction...
#   Mean: 0.10ms | P95: 0.18ms | Throughput: 10365.17/sec
# Running: Format Conversion...
#   Mean: 0.22ms | P95: 0.33ms | Throughput: 4637.15/sec
# Running: Document Classification...
#   Mean: 0.22ms | P95: 0.21ms | Throughput: 4578.99/sec
# Running: Language Detection...
#   Mean: 1.50ms | P95: 1.67ms | Throughput: 664.76/sec
# Running: Semantic Extraction...
#   Mean: 0.30ms | P95: 0.27ms | Throughput: 3302.61/sec
#
# ============================================================
# SUMMARY
# ============================================================
# Total mean time (all benchmarks): 15.07ms
#
# {
#   "metadata": {
#     "timestamp": "2025-11-23T03:45:29.359512",
#     "iterations": 50,
#     "image_size": 512
#   },
#   "benchmarks": [
#     {
#       "name": "image_loading",
#       "iterations": 50,
#       "min_ms": 0.016,
#       "max_ms": 0.121,
#       "mean_ms": 0.024,
#       "median_ms": 0.016,
#       "stdev_ms": 0.018,
#       "p95_ms": 0.043,
#       "p99_ms": null,
#       "throughput_per_sec": 42356.73
#     },
#     {
#       "name": "output_parsing",
#       "iterations": 50,
#       "min_ms": 11.277,
#       "max_ms": 20.911,
#       "mean_ms": 12.705,
#       "median_ms": 12.446,
#       "stdev_ms": 1.321,
#       "p95_ms": 13.957,
#       "p99_ms": null,
#       "throughput_per_sec": 78.71
#     },
#     {
#       "name": "field_extraction",
#       "iterations": 50,
#       "min_ms": 0.064,
#       "max_ms": 0.594,
#       "mean_ms": 0.096,
#       "median_ms": 0.07,
#       "stdev_ms": 0.08,
#       "p95_ms": 0.182,
#       "p99_ms": null,
#       "throughput_per_sec": 10365.17
#     },
#     {
#       "name": "format_conversion",
#       "iterations": 50,
#       "min_ms": 0.15,
#       "max_ms": 1.259,
#       "mean_ms": 0.216,
#       "median_ms": 0.18,
#       "stdev_ms": 0.158,
#       "p95_ms": 0.333,
#       "p99_ms": null,
#       "throughput_per_sec": 4637.15
#     },
#     {
#       "name": "document_classification",
#       "iterations": 50,
#       "min_ms": 0.146,
#       "max_ms": 2.598,
#       "mean_ms": 0.218,
#       "median_ms": 0.169,
#       "stdev_ms": 0.344,
#       "p95_ms": 0.211,
#       "p99_ms": null,
#       "throughput_per_sec": 4578.99
#     },
#     {
#       "name": "language_detection",
#       "iterations": 50,
#       "min_ms": 1.114,
#       "max_ms": 12.733,
#       "mean_ms": 1.504,
#       "median_ms": 1.272,
#       "stdev_ms": 1.626,
#       "p95_ms": 1.672,
#       "p99_ms": null,
#       "throughput_per_sec": 664.76
#     },
#     {
#       "name": "semantic_extraction",
#       "iterations": 50,
#       "min_ms": 0.214,
#       "max_ms": 3.406,
#       "mean_ms": 0.303,
#       "median_ms": 0.236,
#       "stdev_ms": 0.448,
#       "p95_ms": 0.271,
#       "p99_ms": null,
#       "throughput_per_sec": 3302.61
#     }
#   ]
# }

# %%
# ============================================
# CELL 12: API SERVER + CURL TESTS
# ============================================
print("=" * 60)
print("API ENDPOINT TESTS")
print("=" * 60)

import subprocess
import time

# Start server in background
server = subprocess.Popen(['python', 'main.py', '--mode', 'api'])
time.sleep(30)  # Wait for server to initialize

# Health checks
# !curl -s http://localhost:8000/health | python -m json.tool
# !curl -s http://localhost:8000/api/v1/info | python -m json.tool

# OCR v1
print("\n--- API v1 OCR ---")
# !curl -s -X POST http://localhost:8000/api/v1/ocr \
  -F "file=@/kaggle/working/06_Nanonets/tests/asset/invoice1.pdf" | python -m json.tool

# OCR v2
print("\n--- API v2 OCR ---")
# !curl -s -X POST http://localhost:8000/api/v1/v2/ocr \
  -F "file=@/kaggle/working/06_Nanonets/tests/asset/invoice1.pdf" | python -m json.tool

# Batch
print("\n--- Batch OCR ---")
# !curl -s -X POST http://localhost:8000/api/v1/ocr/batch \
  -F "files=@/kaggle/working/06_Nanonets/tests/asset/invoice1.pdf" \
  -F "files=@/kaggle/working/06_Nanonets/tests/asset/invoice2.pdf" | python -m json.tool

# Classification
print("\n--- Document Classification ---")
# !curl -s -X POST http://localhost:8000/api/v1/classify \
  -F "file=@/kaggle/working/06_Nanonets/tests/asset/docparsing_example1.jpg" | python -m json.tool

# Language detection
print("\n--- Language Detection ---")
# !curl -s -X POST http://localhost:8000/api/v1/detect-language \
  -F "file=@/kaggle/working/06_Nanonets/tests/asset/ocr_example1.jpg" | python -m json.tool

# Entity extraction
print("\n--- Entity Extraction ---")
# !curl -s -X POST http://localhost:8000/api/v1/extract-entities \
  -F "file=@/kaggle/working/06_Nanonets/tests/asset/invoice1.pdf" | python -m json.tool

# Structured extraction
print("\n--- Structured Extraction ---")
# !curl -s -X POST http://localhost:8000/api/v1/structured \
  -F "file=@/kaggle/working/06_Nanonets/tests/asset/invoice1.pdf" | python -m json.tool

# Cleanup
server.terminate()
print("\n✓ API endpoint tests completed\n")
# Out:
# ============================================================
# API ENDPOINT TESTS
# ============================================================
# 2025-11-23 03:45:36.907455: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763869536.934368     424 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763869536.942095     424 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# WARNING:passlib.handlers.bcrypt:(trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/passlib/handlers/bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# INFO:     Started server process [424]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# ============================================================
# Nanonets VL OCR System
# ============================================================
#   Mode: api
#   Model: nanonets/Nanonets-OCR-s
#   API: http://0.0.0.0:8000
# {"timestamp": "2025-11-23T03:46:01.075984Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e654e4ba9da24157", "method": "GET", "path": "/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:46:01.076884Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e654e4ba9da24157", "status_code": 404}
# INFO:     127.0.0.1:39090 - "GET /health HTTP/1.1" 404 Not Found
# {
#     "detail": "Not Found"
# }
# {"timestamp": "2025-11-23T03:46:01.238527Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_0efbc750d25c45d3", "method": "GET", "path": "/api/v1/info", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:46:01.239561Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_0efbc750d25c45d3", "status_code": 404}
# INFO:     127.0.0.1:39094 - "GET /api/v1/info HTTP/1.1" 404 Not Found
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {
#     "detail": "Not Found"
# }
#
# --- API v1 OCR ---
# {"timestamp": "2025-11-23T03:46:01.435755Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_7307bb9ab5c1407b", "method": "POST", "path": "/api/v1/ocr", "client": "127.0.0.1"}
# INFO:nanonets.api:Request started
# `torch_dtype` is deprecated! Use `dtype` instead!
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Processing page 1/1...
# [cuda] Loading model: nanonets/Nanonets-OCR-s
# [cuda] CUDA available. Loading with optimizations.
# [cuda] Warning: Optimized loading failed: Using `bitsandbytes` 8-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes`
# Fetching 2 files: 100%|██████████| 2/2 [00:00<00:00, 23045.63it/s]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:07<00:00,  3.95s/it]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Page 1 completed in 34.00s
# {"timestamp": "2025-11-23T03:46:35.597059Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_7307bb9ab5c1407b", "status_code": 200}
# INFO:     127.0.0.1:39110 - "POST /api/v1/ocr HTTP/1.1" 200 OK
# {
#     "job_id": "ebfac75d-35d4-471d-9365-1a5c9512fc0f",
#     "status": "completed",
#     "processing_time_ms": 34158,
#     "document": {
#         "filename": "invoice1.pdf",
#         "file_size_mb": 0.014665603637695312,
#         "file_type": "PDF",
#         "total_pages": 1
#     },
#     "result": {
#         "text": "\n--- Page 1 ---\nSuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#         "pages": [
#             {
#                 "page_number": 1,
#                 "text": "SuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#                 "success": true
#             }
#         ],
#         "tables_count": 1,
#         "equations_count": 3,
#         "formatted_output": "{\n  \"pages\": [\n    {\n      \"page_number\": 1,\n      \"raw_text\": \"SuperStore\\n\\nINVOICE\\n# 21435\\n\\nBill To:\\n**Trudy Glocke**\\n\\nShip To:\\n**Kuantan, Pahang, Malaysia**\\n\\nDate: Jan 25 2013\\nShip Mode: Same Day\\n\\nBalance Due: $7,325.56\\n\\n<table>\\n<thead>\\n<tr>\\n<th>Item</th>\\n<th>Quantity</th>\\n<th>Rate</th>\\n<th>Amount</th>\\n</tr>\\n</thead>\\n<tbody>\\n<tr>\\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\\n<td>7</td>\\n<td>$1,014.72</td>\\n<td>$7,103.04</td>\\n</tr>\\n</tbody>\\n</table>\\n\\nSubtotal: $7,103.04\\nShipping: $222.52\\nTotal: $7,325.56\\n\\nNotes:\\nThanks for your business!\\n\\nTerms:\\nOrder ID : IN-2013-TG2164078-41299\",\n      \"tables_html\": [\n        \"<table>\\n<thead>\\n<tr>\\n<th>Item</th>\\n<th>Quantity</th>\\n<th>Rate</th>\\n<th>Amount</th>\\n</tr>\\n</thead>\\n<tbody>\\n<tr>\\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\\n<td>7</td>\\n<td>$1,014.72</td>\\n<td>$7,103.04</td>\\n</tr>\\n</tbody>\\n</table>\"\n      ],\n      \"tables_csv\": [\n        \"Item,Quantity,Rate,Amount\\n\\\"Ikea 3-Shelf Cabinet, Mobile Bookcases, Furniture, FUR-BO-4845\\\",7,\\\"$1,014.72\\\",\\\"$7,103.04\\\"\\n\"\n      ],\n      \"latex_equations\": [\n        \"7,325.56\\n\\n<table>\\n<thead>\\n<tr>\\n<th>Item</th>\\n<th>Quantity</th>\\n<th>Rate</th>\\n<th>Amount</th>\\n</tr>\\n</thead>\\n<tbody>\\n<tr>\\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\\n<td>7</td>\\n<td>\",\n        \"7,103.04</td>\\n</tr>\\n</tbody>\\n</table>\\n\\nSubtotal:\",\n        \"222.52\\nTotal:\"\n      ],\n      \"image_descriptions\": [],\n      \"watermarks\": [],\n      \"page_numbers_extracted\": [],\n      \"checkboxes\": []\n    }\n  ]\n}",
#         "document_type": "invoice",
#         "classification_confidence": 0.64,
#         "language": "en",
#         "structured": {
#             "document_type": "invoice",
#             "confidence": 0.64,
#             "language": "en",
#             "extracted_fields": {
#                 "date": "Jan 25 2013",
#                 "total": "7,325.56",
#                 "invoice_number": "21435",
#                 "ship_to": {
#                     "location": "Kuantan, Pahang, Malaysia"
#                 },
#                 "subtotal": "7,103.04",
#                 "shipping": "222.52",
#                 "ship_mode": "Same Day",
#                 "order_id": "IN-2013-TG2164078-41299",
#                 "notes": "Thanks for your business!",
#                 "terms": "Order ID : IN-2013-TG2164078-41299"
#             },
#             "line_items": [
#                 {
#                     "description": "Ikea 3-Shelf Cabinet, MobileBookcases, Furniture, FUR-BO-4845",
#                     "quantity": "7",
#                     "rate": "$1,014.72",
#                     "amount": "$7,103.04"
#                 }
#             ],
#             "entities": [
#                 {
#                     "type": "person",
#                     "value": "Trudy Glocke",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "person",
#                     "value": "Same Day",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "person",
#                     "value": "Shelf Cabinet",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "money",
#                     "value": "$7,325.56",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "money",
#                     "value": "$1,014.72",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "money",
#                     "value": "$7,103.04",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "money",
#                     "value": "$7,103.04",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "money",
#                     "value": "$222.52",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "money",
#                     "value": "$7,325.56",
#                     "confidence": 0.8
#                 },
#                 {
#                     "type": "phone",
#                     "value": "2164078-4129",
#                     "confidence": 0.8
#                 }
#             ],
#             "raw": {
#                 "text": "\n--- Page 1 ---\nSuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#                 "tables_html": [
#                     "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#                 ],
#                 "pages": [
#                     {
#                         "page_number": 1,
#                         "raw_text": "SuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#                         "tables_html": [
#                             "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#                         ],
#                         "tables_csv": [
#                             "Item,Quantity,Rate,Amount\n\"Ikea 3-Shelf Cabinet, Mobile Bookcases, Furniture, FUR-BO-4845\",7,\"$1,014.72\",\"$7,103.04\"\n"
#                         ],
#                         "latex_equations": [
#                             "7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>",
#                             "7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal:",
#                             "222.52\nTotal:"
#                         ],
#                         "image_descriptions": [],
#                         "watermarks": [],
#                         "page_numbers_extracted": [],
#                         "checkboxes": []
#                     }
#                 ]
#             }
#         }
#     },
#     "extracted_fields": {
#         "Company Name": "",
#         "Company Address": "",
#         "Company Phone": "",
#         "Company Email": "",
#         "Company Website": "",
#         "Invoice Number": "",
#         "Invoice Date": "",
#         "Due Date": "",
#         "PO Number": "",
#         "Reference Number": "",
#         "Bill To Name": "",
#         "Bill To Address": "",
#         "Bill To Phone": "",
#         "Bill To Email": "",
#         "Ship To Name": "",
#         "Ship To Address": "",
#         "Ship To Phone": "",
#         "Ship To Email": "",
#         "Subtotal": "$7,103.04",
#         "Tax Amount": "",
#         "Tax Rate": "",
#         "Discount Amount": "",
#         "Shipping Cost": "",
#         "Total Amount": "",
#         "Amount Paid": "",
#         "Amount Due": "",
#         "Currency": "",
#         "Payment Terms": "",
#         "Payment Method": "",
#         "Bank Name": "",
#         "Account Number": "",
#         "SWIFT Code": "",
#         "Item Description": "",
#         "Item Quantity": "",
#         "Item Unit Price": "",
#         "Item Total": "",
#         "Customer ID": "",
#         "Vendor ID": "",
#         "Department": "",
#         "Project Code": "",
#         "Notes": "Thanks for your business!",
#         "Terms and Conditions": "",
#         "Signature": "",
#         "Date of Signature": "",
#         "Sales Person": "",
#         "Customer Service Rep": "",
#         "Approval Status": "",
#         "Document Type": "",
#         "Purchase Order Number": "",
#         "Contract Number": "",
#         "License Number": "",
#         "Registration Number": ""
#     },
#     "confidence_scores": {
#         "Company Name": 0.0,
#         "Company Address": 0.0,
#         "Company Phone": 0.0,
#         "Company Email": 0.0,
#         "Company Website": 0.0,
#         "Invoice Number": 0.0,
#         "Invoice Date": 0.0,
#         "Due Date": 0.0,
#         "PO Number": 0.0,
#         "Reference Number": 0.0,
#         "Bill To Name": 0.0,
#         "Bill To Address": 0.0,
#         "Bill To Phone": 0.0,
#         "Bill To Email": 0.0,
#         "Ship To Name": 0.0,
#         "Ship To Address": 0.0,
#         "Ship To Phone": 0.0,
#         "Ship To Email": 0.0,
#         "Subtotal": 0.87,
#         "Tax Amount": 0.0,
#         "Tax Rate": 0.0,
#         "Discount Amount": 0.0,
#         "Shipping Cost": 0.0,
#         "Total Amount": 0.0,
#         "Amount Paid": 0.0,
#         "Amount Due": 0.0,
#         "Currency": 0.0,
#         "Payment Terms": 0.0,
#         "Payment Method": 0.0,
#         "Bank Name": 0.0,
#         "Account Number": 0.0,
#         "SWIFT Code": 0.0,
#         "Item Description": 0.0,
#         "Item Quantity": 0.0,
#         "Item Unit Price": 0.0,
#         "Item Total": 0.0,
#         "Customer ID": 0.0,
#         "Vendor ID": 0.0,
#         "Department": 0.0,
#         "Project Code": 0.0,
#         "Notes": 0.9099999999999999,
#         "Terms and Conditions": 0.0,
#         "Signature": 0.0,
#         "Date of Signature": 0.0,
#         "Sales Person": 0.0,
#         "Customer Service Rep": 0.0,
#         "Approval Status": 0.0,
#         "Document Type": 0.0,
#         "Purchase Order Number": 0.0,
#         "Contract Number": 0.0,
#         "License Number": 0.0,
#         "Registration Number": 0.0
#     }
# }
#
# --- API v2 OCR ---
# {"timestamp": "2025-11-23T03:46:35.740212Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_ad5de5fee2ff495b", "method": "POST", "path": "/api/v1/v2/ocr", "client": "127.0.0.1"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 21.83s
# {"timestamp": "2025-11-23T03:46:57.662646Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_ad5de5fee2ff495b", "status_code": 200}
# INFO:     127.0.0.1:58626 - "POST /api/v1/v2/ocr HTTP/1.1" 200 OK
# {
#     "api_version": "2.0",
#     "job_id": "b2b8181b-dc53-4b3f-a8e0-c7f20fbe48aa",
#     "status": "completed",
#     "processing_time_ms": 21919,
#     "document": {
#         "filename": "invoice1.pdf",
#         "file_size_mb": 0.015,
#         "file_type": "PDF",
#         "total_pages": 1
#     },
#     "result": {
#         "document_type": "invoice",
#         "confidence": 0.64,
#         "language": "en",
#         "extracted_fields": {
#             "date": "Jan 25 2013",
#             "total": "7,325.56",
#             "invoice_number": "21435",
#             "ship_to": {
#                 "location": "Kuantan, Pahang, Malaysia"
#             },
#             "subtotal": "7,103.04",
#             "shipping": "222.52",
#             "ship_mode": "Same Day",
#             "order_id": "IN-2013-TG2164078-41299",
#             "notes": "Thanks for your business!",
#             "terms": "Order ID : IN-2013-TG2164078-41299"
#         },
#         "line_items": [
#             {
#                 "description": "Ikea 3-Shelf Cabinet, MobileBookcases, Furniture, FUR-BO-4845",
#                 "quantity": "7",
#                 "rate": "$1,014.72",
#                 "amount": "$7,103.04"
#             }
#         ],
#         "entities": [
#             {
#                 "type": "person",
#                 "value": "Trudy Glocke",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "person",
#                 "value": "Same Day",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "person",
#                 "value": "Shelf Cabinet",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "money",
#                 "value": "$7,325.56",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "money",
#                 "value": "$1,014.72",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "money",
#                 "value": "$7,103.04",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "money",
#                 "value": "$7,103.04",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "money",
#                 "value": "$222.52",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "money",
#                 "value": "$7,325.56",
#                 "confidence": 0.8
#             },
#             {
#                 "type": "phone",
#                 "value": "2164078-4129",
#                 "confidence": 0.8
#             }
#         ],
#         "raw": {
#             "text": "\n--- Page 1 ---\nSuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#             "tables_html": [
#                 "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#             ],
#             "pages": [
#                 {
#                     "page_number": 1,
#                     "raw_text": "SuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#                     "tables_html": [
#                         "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#                     ],
#                     "tables_csv": [
#                         "Item,Quantity,Rate,Amount\n\"Ikea 3-Shelf Cabinet, Mobile Bookcases, Furniture, FUR-BO-4845\",7,\"$1,014.72\",\"$7,103.04\"\n"
#                     ],
#                     "latex_equations": [
#                         "7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>",
#                         "7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal:",
#                         "222.52\nTotal:"
#                     ],
#                     "image_descriptions": [],
#                     "watermarks": [],
#                     "page_numbers_extracted": [],
#                     "checkboxes": []
#                 }
#             ]
#         }
#     }
# }
#
# --- Batch OCR ---
# {"timestamp": "2025-11-23T03:46:57.811075Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_f6eb56c26708493f", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 21.91s
# Processing page 1/1...
# Page 1 completed in 22.98s
# {"timestamp": "2025-11-23T03:47:42.877915Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f6eb56c26708493f", "status_code": 200}
# INFO:     127.0.0.1:55228 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# {
#     "batch_id": "1108217e-0cf6-4c63-a009-3e6fa3e72508",
#     "status": "completed",
#     "total_files": 2,
#     "successful": 2,
#     "failed": 0,
#     "processing_time_ms": 45063,
#     "results": [
#         {
#             "filename": "invoice1.pdf",
#             "status": "completed",
#             "result": {
#                 "document_type": "invoice",
#                 "confidence": 0.64,
#                 "language": "en",
#                 "extracted_fields": {
#                     "date": "Jan 25 2013",
#                     "total": "7,325.56",
#                     "invoice_number": "21435",
#                     "ship_to": {
#                         "location": "Kuantan, Pahang, Malaysia"
#                     },
#                     "subtotal": "7,103.04",
#                     "shipping": "222.52",
#                     "ship_mode": "Same Day",
#                     "order_id": "IN-2013-TG2164078-41299",
#                     "notes": "Thanks for your business!",
#                     "terms": "Order ID : IN-2013-TG2164078-41299"
#                 },
#                 "line_items": [
#                     {
#                         "description": "Ikea 3-Shelf Cabinet, MobileBookcases, Furniture, FUR-BO-4845",
#                         "quantity": "7",
#                         "rate": "$1,014.72",
#                         "amount": "$7,103.04"
#                     }
#                 ],
#                 "entities": [
#                     {
#                         "type": "person",
#                         "value": "Trudy Glocke",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "person",
#                         "value": "Same Day",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "person",
#                         "value": "Shelf Cabinet",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$7,325.56",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$1,014.72",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$7,103.04",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$7,103.04",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$222.52",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$7,325.56",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "phone",
#                         "value": "2164078-4129",
#                         "confidence": 0.8
#                     }
#                 ],
#                 "raw": {
#                     "text": "\n--- Page 1 ---\nSuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#                     "tables_html": [
#                         "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#                     ],
#                     "pages": [
#                         {
#                             "page_number": 1,
#                             "raw_text": "SuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#                             "tables_html": [
#                                 "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#                             ],
#                             "tables_csv": [
#                                 "Item,Quantity,Rate,Amount\n\"Ikea 3-Shelf Cabinet, Mobile Bookcases, Furniture, FUR-BO-4845\",7,\"$1,014.72\",\"$7,103.04\"\n"
#                             ],
#                             "latex_equations": [
#                                 "7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>",
#                                 "7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal:",
#                                 "222.52\nTotal:"
#                             ],
#                             "image_descriptions": [],
#                             "watermarks": [],
#                             "page_numbers_extracted": [],
#                             "checkboxes": []
#                         }
#                     ]
#                 }
#             }
#         },
#         {
#             "filename": "invoice2.pdf",
#             "status": "completed",
#             "result": {
#                 "document_type": "invoice",
#                 "confidence": 0.64,
#                 "language": "en",
#                 "extracted_fields": {
#                     "date": "Jan 10 2013",
#                     "total": "12,725.04",
#                     "invoice_number": "14380",
#                     "bill_to": {
#                         "name": "Trudy Schmidt"
#                     },
#                     "ship_to": {
#                         "location": "London, England,"
#                     },
#                     "subtotal": "14,029.09",
#                     "discount": "1,402.91",
#                     "shipping": "98.86",
#                     "ship_mode": "Standard Class",
#                     "order_id": "IT-2013-TS21655139-41284",
#                     "notes": "Thanks for your business!",
#                     "terms": "Order ID : IT-2013-TS21655139-41284"
#                 },
#                 "line_items": [
#                     {
#                         "description": "Hewlett Fax Machine, High-SpeedCopiers, Technology, TEC-CO-4577",
#                         "quantity": "7",
#                         "rate": "$2,004.16",
#                         "amount": "$14,029.09"
#                     }
#                 ],
#                 "entities": [
#                     {
#                         "type": "person",
#                         "value": "Trudy Schmidt",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "person",
#                         "value": "United Kingdom",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "person",
#                         "value": "Hewlett Fax",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$12,725.04",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$2,004.16",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$14,029.09",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$14,029.09",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$1,402.91",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$98.86",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "money",
#                         "value": "$12,725.04",
#                         "confidence": 0.8
#                     },
#                     {
#                         "type": "phone",
#                         "value": "21655139-4128",
#                         "confidence": 0.8
#                     }
#                 ],
#                 "raw": {
#                     "text": "\n--- Page 1 ---\nSuperStore\n\nINVOICE\n# 14380\n\nBill To:\nTrudy Schmidt\n\nShip To:\nLondon, England,\nUnited Kingdom\n\nDate: Jan 10 2013\nShip Mode: Standard Class\n\nBalance Due: $12,725.04\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Hewlett Fax Machine, High-Speed</strong><br>Copiers, Technology, TEC-CO-4577</td>\n<td>7</td>\n<td>$2,004.16</td>\n<td>$14,029.09</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $14,029.09\nDiscount (10%): $1,402.91\nShipping: $98.86\nTotal: $12,725.04\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IT-2013-TS21655139-41284",
#                     "tables_html": [
#                         "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Hewlett Fax Machine, High-Speed</strong><br/>Copiers, Technology, TEC-CO-4577</td>\n<td>7</td>\n<td>$2,004.16</td>\n<td>$14,029.09</td>\n</tr>\n</tbody>\n</table>"
#                     ],
#                     "pages": [
#                         {
#                             "page_number": 1,
#                             "raw_text": "SuperStore\n\nINVOICE\n# 14380\n\nBill To:\nTrudy Schmidt\n\nShip To:\nLondon, England,\nUnited Kingdom\n\nDate: Jan 10 2013\nShip Mode: Standard Class\n\nBalance Due: $12,725.04\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Hewlett Fax Machine, High-Speed</strong><br>Copiers, Technology, TEC-CO-4577</td>\n<td>7</td>\n<td>$2,004.16</td>\n<td>$14,029.09</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $14,029.09\nDiscount (10%): $1,402.91\nShipping: $98.86\nTotal: $12,725.04\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IT-2013-TS21655139-41284",
#                             "tables_html": [
#                                 "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Hewlett Fax Machine, High-Speed</strong><br/>Copiers, Technology, TEC-CO-4577</td>\n<td>7</td>\n<td>$2,004.16</td>\n<td>$14,029.09</td>\n</tr>\n</tbody>\n</table>"
#                             ],
#                             "tables_csv": [
#                                 "Item,Quantity,Rate,Amount\n\"Hewlett Fax Machine, High-Speed Copiers, Technology, TEC-CO-4577\",7,\"$2,004.16\",\"$14,029.09\"\n"
#                             ],
#                             "latex_equations": [
#                                 "12,725.04\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Hewlett Fax Machine, High-Speed</strong><br>Copiers, Technology, TEC-CO-4577</td>\n<td>7</td>\n<td>",
#                                 "14,029.09</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal:",
#                                 "1,402.91\nShipping:"
#                             ],
#                             "image_descriptions": [],
#                             "watermarks": [],
#                             "page_numbers_extracted": [],
#                             "checkboxes": []
#                         }
#                     ]
#                 }
#             }
#         }
#     ]
# }
#
# --- Document Classification ---
# {"timestamp": "2025-11-23T03:47:43.020384Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_0ceebab785984a58", "method": "POST", "path": "/api/v1/classify", "client": "127.0.0.1"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 156.68s
# {"timestamp": "2025-11-23T03:50:19.972502Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_0ceebab785984a58", "status_code": 200}
# INFO:     127.0.0.1:54394 - "POST /api/v1/classify HTTP/1.1" 200 OK
# {
#     "document_type": "form",
#     "confidence": 0.33,
#     "all_scores": {
#         "invoice": 0.0,
#         "receipt": 0.0,
#         "contract": 0.0,
#         "form": 0.167,
#         "letter": 0.0,
#         "report": 0.0,
#         "id_document": 0.0,
#         "bank_statement": 0.0,
#         "tax_document": 0.0,
#         "medical": 0.0
#     },
#     "keywords_found": [
#         "form"
#     ]
# }
#
# --- Language Detection ---
# {"timestamp": "2025-11-23T03:50:20.112888Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_17b9eeab45d5405b", "method": "POST", "path": "/api/v1/detect-language", "client": "127.0.0.1"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 6.34s
# {"timestamp": "2025-11-23T03:50:26.601835Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_17b9eeab45d5405b", "status_code": 200}
# INFO:     127.0.0.1:47608 - "POST /api/v1/detect-language HTTP/1.1" 200 OK
# {
#     "primary_language": "ko",
#     "confidence": 0.43,
#     "script_detected": "latin",
#     "is_multilingual": true,
#     "secondary_languages": [
#         "en"
#     ]
# }
#
# --- Entity Extraction ---
# {"timestamp": "2025-11-23T03:50:26.741175Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_bd6e2c6eec5b4f68", "method": "POST", "path": "/api/v1/extract-entities", "client": "127.0.0.1"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 22.09s
# {"timestamp": "2025-11-23T03:50:48.906623Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_bd6e2c6eec5b4f68", "status_code": 200}
# INFO:     127.0.0.1:47624 - "POST /api/v1/extract-entities HTTP/1.1" 200 OK
# {
#     "entities": [
#         {
#             "type": "person",
#             "value": "Trudy Glocke",
#             "confidence": 0.8
#         },
#         {
#             "type": "person",
#             "value": "Same Day",
#             "confidence": 0.8
#         },
#         {
#             "type": "person",
#             "value": "Shelf Cabinet",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,325.56",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$1,014.72",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,103.04",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,103.04",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$222.52",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,325.56",
#             "confidence": 0.8
#         },
#         {
#             "type": "phone",
#             "value": "2164078-4129",
#             "confidence": 0.8
#         }
#     ],
#     "fields": {
#         "amount": {
#             "value": "7,325.56",
#             "confidence": 0.85,
#             "context": "payment_info"
#         },
#         "id_number": {
#             "value": "IN-2013-TG2164078-41299",
#             "confidence": 0.85,
#             "context": "identification"
#         }
#     },
#     "summary": "Document contains: 3 person(s), 6 monetary value(s).",
#     "key_points": [
#         "-- Page 1 ---",
#         "*Trudy Glocke**",
#         "*Kuantan, Pahang, Malaysia**",
#         "s:"
#     ]
# }
#
# --- Structured Extraction ---
# {"timestamp": "2025-11-23T03:50:49.048410Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8aba038ea822418d", "method": "POST", "path": "/api/v1/structured", "client": "127.0.0.1"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 22.26s
# {"timestamp": "2025-11-23T03:51:11.402057Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8aba038ea822418d", "status_code": 200}
# INFO:     127.0.0.1:45308 - "POST /api/v1/structured HTTP/1.1" 200 OK
# {
#     "document_type": "invoice",
#     "confidence": 0.64,
#     "language": "en",
#     "extracted_fields": {
#         "date": "Jan 25 2013",
#         "total": "7,325.56",
#         "invoice_number": "21435",
#         "ship_to": {
#             "location": "Kuantan, Pahang, Malaysia"
#         },
#         "subtotal": "7,103.04",
#         "shipping": "222.52",
#         "ship_mode": "Same Day",
#         "order_id": "IN-2013-TG2164078-41299",
#         "notes": "Thanks for your business!",
#         "terms": "Order ID : IN-2013-TG2164078-41299"
#     },
#     "line_items": [
#         {
#             "description": "Ikea 3-Shelf Cabinet, MobileBookcases, Furniture, FUR-BO-4845",
#             "quantity": "7",
#             "rate": "$1,014.72",
#             "amount": "$7,103.04"
#         }
#     ],
#     "entities": [
#         {
#             "type": "person",
#             "value": "Trudy Glocke",
#             "confidence": 0.8
#         },
#         {
#             "type": "person",
#             "value": "Same Day",
#             "confidence": 0.8
#         },
#         {
#             "type": "person",
#             "value": "Shelf Cabinet",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,325.56",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$1,014.72",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,103.04",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,103.04",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$222.52",
#             "confidence": 0.8
#         },
#         {
#             "type": "money",
#             "value": "$7,325.56",
#             "confidence": 0.8
#         },
#         {
#             "type": "phone",
#             "value": "2164078-4129",
#             "confidence": 0.8
#         }
#     ],
#     "raw": {
#         "text": "\n--- Page 1 ---\nSuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#         "tables_html": [
#             "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#         ],
#         "pages": [
#             {
#                 "page_number": 1,
#                 "raw_text": "SuperStore\n\nINVOICE\n# 21435\n\nBill To:\n**Trudy Glocke**\n\nShip To:\n**Kuantan, Pahang, Malaysia**\n\nDate: Jan 25 2013\nShip Mode: Same Day\n\nBalance Due: $7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal: $7,103.04\nShipping: $222.52\nTotal: $7,325.56\n\nNotes:\nThanks for your business!\n\nTerms:\nOrder ID : IN-2013-TG2164078-41299",
#                 "tables_html": [
#                     "<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br/>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>$1,014.72</td>\n<td>$7,103.04</td>\n</tr>\n</tbody>\n</table>"
#                 ],
#                 "tables_csv": [
#                     "Item,Quantity,Rate,Amount\n\"Ikea 3-Shelf Cabinet, Mobile Bookcases, Furniture, FUR-BO-4845\",7,\"$1,014.72\",\"$7,103.04\"\n"
#                 ],
#                 "latex_equations": [
#                     "7,325.56\n\n<table>\n<thead>\n<tr>\n<th>Item</th>\n<th>Quantity</th>\n<th>Rate</th>\n<th>Amount</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong>Ikea 3-Shelf Cabinet, Mobile</strong><br>Bookcases, Furniture, FUR-BO-4845</td>\n<td>7</td>\n<td>",
#                     "7,103.04</td>\n</tr>\n</tbody>\n</table>\n\nSubtotal:",
#                     "222.52\nTotal:"
#                 ],
#                 "image_descriptions": [],
#                 "watermarks": [],
#                 "page_numbers_extracted": [],
#                 "checkboxes": []
#             }
#         ]
#     }
# }
#
# ✓ API endpoint tests completed
# INFO:nanonets.api:Request completed

# %%
# ============================================
# CELL 13: LOAD TEST WITH LOCUST
# ============================================
print("=" * 60)
print("LOAD TEST (LOCUST)")
print("=" * 60)

import subprocess
import time

# Start server
server = subprocess.Popen(['python', 'main.py', '--mode', 'api'])
time.sleep(30)

# Run locust
# !locust -f tests/performance/locustfile.py --host=http://localhost:8000 --headless -u 10 -r 2 -t 60s

# Cleanup
server.terminate()
print("")
# Out:
# ============================================================
# LOAD TEST (LOCUST)
# ============================================================
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [424]
# 2025-11-23 03:51:17.451269: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763869877.475871     485 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763869877.483670     485 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# WARNING:passlib.handlers.bcrypt:(trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/passlib/handlers/bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# INFO:     Started server process [485]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# ============================================================
# Nanonets VL OCR System
# ============================================================
#   Mode: api
#   Model: nanonets/Nanonets-OCR-s
#   API: http://0.0.0.0:8000
# [2025-11-23 03:51:43,310] 1544c18f1fe6/INFO/locust.main: Starting Locust 2.42.5
# {"timestamp": "2025-11-23T03:51:43.355700Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d58e051e89a54ac3", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:43.357185Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_5cf0294a47874359", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:43.357480Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d58e051e89a54ac3", "status_code": 200}
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# [2025-11-23 03:51:43,332] 1544c18f1fe6/INFO/locust.main: Run time limit set to 60 seconds
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Load test starting...
# Target host: http://localhost:8000
# [2025-11-23 03:51:43,333] 1544c18f1fe6/INFO/locust.runners: Ramping to 10 users at a rate of 2.00 per second
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# `torch_dtype` is deprecated! Use `dtype` instead!
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Processing page 1/1...
# [cuda] Loading model: nanonets/Nanonets-OCR-s
# [cuda] CUDA available. Loading with optimizations.
# [cuda] Warning: Optimized loading failed: Using `bitsandbytes` 8-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes`
# Fetching 2 files: 100%|██████████| 2/2 [00:00<00:00, 19784.45it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
#
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
#
# [2025-11-23 03:51:47,337] 1544c18f1fe6/INFO/locust.runners: All users spawned: {"AuthenticatedOCRUser": 4, "BatchProcessingUser": 3, "OCRUser": 3} (10 total users)
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# Loading checkpoint shards:  50%|█████     | 1/2 [00:04<00:04,  4.86s/it]
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# Loading checkpoint shards: 100%|██████████| 2/2 [00:07<00:00,  3.69s/it]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       1     0(0.00%) |     24      24      24     24 |    0.00        0.00
#
# Page 1 completed in 12.30s
# Processing page 1/1...
# Page 1 completed in 0.53s
# Processing page 1/1...
# Page 1 completed in 0.52s
# {"timestamp": "2025-11-23T03:51:56.729853Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_5cf0294a47874359", "status_code": 200}
# {"timestamp": "2025-11-23T03:51:56.730943Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_124a3601e65f4be7", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41604 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:51:56.734590Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_124a3601e65f4be7", "status_code": 200}
# {"timestamp": "2025-11-23T03:51:56.734834Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_88ddf885384c4b5b", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:56.735295Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_bf182dc4a2284f79", "method": "POST", "path": "/api/v1/classify", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:56.735609Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_20551bf44eae43f9", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:56.735881Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_ec5a0fe3cc9246cd", "method": "POST", "path": "/api/v1/classify", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:56.736143Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c751ecd32c3e4555", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:56.736414Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d2e70dc27672439c", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:56.736643Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_1299fb3f3f484742", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:51:56.736856Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c22d24e6a1dc45a3", "method": "GET", "path": "/api/v1/ready", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:51:56.742453Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_88ddf885384c4b5b", "status_code": 200}
# {"timestamp": "2025-11-23T03:51:56.742742Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c751ecd32c3e4555", "status_code": 200}
# {"timestamp": "2025-11-23T03:51:56.742937Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_1299fb3f3f484742", "status_code": 200}
# {"timestamp": "2025-11-23T03:51:56.743103Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c22d24e6a1dc45a3", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41666 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41680 - "GET /api/v1/ready HTTP/1.1" 200 OK
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       3     0(0.00%) |   8606      24   13384  12000 |    0.00        0.00
# POST     /api/v1/ocr/batch       1     0(0.00%) |  13385   13385   13385  13385 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       4     0(0.00%) |   9801      24   13385  12000 |    0.00        0.00
#
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /api/v1/health       4     0(0.00%) |   9703      24   13384  12000 |    0.20        0.00
# POST     /api/v1/ocr/batch       1     0(0.00%) |  13385   13385   13385  13385 |    0.10        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       5     0(0.00%) |  10439      24   13385  13000 |    0.30        0.00
#
# Processing page 1/1...
# Page 1 completed in 0.49s
# Processing page 1/1...
# Page 1 completed in 0.54s
# Processing page 1/1...
# Page 1 completed in 0.52s
# Processing page 1/1...
# Page 1 completed in 0.52s
# Processing page 1/1...
# Page 1 completed in 0.49s
# Processing page 1/1...
# Page 1 completed in 0.52s
# Processing page 1/1...
# Page 1 completed in 0.52s
# Processing page 1/1...
# Page 1 completed in 0.52s
# {"timestamp": "2025-11-23T03:52:00.902047Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_052a7790f11f4ace", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.902666Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_bf182dc4a2284f79", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.902868Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_20551bf44eae43f9", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.903033Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_ec5a0fe3cc9246cd", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.903250Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d2e70dc27672439c", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.904292Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_a706ff1c0f2d4731", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41628 - "POST /api/v1/classify HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41638 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41642 - "POST /api/v1/classify HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41656 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.906025Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_052a7790f11f4ace", "status_code": 200}
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.907527Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_a706ff1c0f2d4731", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.910336Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6f447886dc9844ca", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.911043Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c547c894f4044725", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.911636Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6f447886dc9844ca", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.911865Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c547c894f4044725", "status_code": 200}
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.914858Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e3eb09254e684da1", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.915636Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_39a7e739d95a4d82", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.916517Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e3eb09254e684da1", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.916733Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_39a7e739d95a4d82", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.919370Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_beda4e5f5cf143f2", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.920028Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_7debc644b7354cd0", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.920593Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_beda4e5f5cf143f2", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.920791Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_7debc644b7354cd0", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.923439Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_5bac2e36d8d946c3", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.924116Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_2782e63451fd4ab2", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.924762Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_5bac2e36d8d946c3", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.924978Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_2782e63451fd4ab2", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.927565Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_5c18c28321ba4edd", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.928269Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_b407fd5a59bb4b42", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.929090Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_5c18c28321ba4edd", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.929333Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b407fd5a59bb4b42", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.932194Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_1acafdc952544d91", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.933015Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_367ebdce0822406a", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.933576Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_1acafdc952544d91", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.933755Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_367ebdce0822406a", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.936196Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c7f42fd3f4374b66", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.936888Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c9bfcb0a00bc4eb2", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.937471Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c7f42fd3f4374b66", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:00.937656Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c9bfcb0a00bc4eb2", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.939619Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e439b9457d804f80", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.940195Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e439b9457d804f80", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:00.941813Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_0c3d01f097674298", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:00.942478Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_0c3d01f097674298", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# POST     /api/v1/classify       2     0(0.00%) |  16022   15511   16534  16000 |    0.00        0.00
# GET      /api/v1/health      23     0(0.00%) |   2469       2   13563      4 |    0.20        0.00
# POST     /api/v1/ocr/batch       3     0(0.00%) |  14504   13385   15565  15000 |    0.10        0.00
# GET      /api/v1/ready       1     0(0.00%) |  13509   13509   13509  13509 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated      29     0(0.00%) |   5030       2   16534      5 |    0.30        0.00
#
# {"timestamp": "2025-11-23T03:52:02.615584Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_f0dd486f48ec404b", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:02.616585Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f0dd486f48ec404b", "status_code": 200}
# INFO:     127.0.0.1:41642 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:03.066186Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_b43e597af58f416b", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.067516Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b43e597af58f416b", "status_code": 200}
# INFO:     127.0.0.1:41680 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# POST     /api/v1/classify       2     0(0.00%) |  16022   15511   16534  16000 |    0.20        0.00
# GET      /api/v1/health      25     0(0.00%) |   2272       2   13563      4 |    2.20        0.00
# POST     /api/v1/ocr/batch       3     0(0.00%) |  14504   13385   15565  15000 |    0.30        0.00
# GET      /api/v1/ready       1     0(0.00%) |  13509   13509   13509  13509 |    0.10        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated      31     0(0.00%) |   4705       2   16534      5 |    2.80        0.00
#
# {"timestamp": "2025-11-23T03:52:03.794565Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_22e2ab2740834d06", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.795392Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_22e2ab2740834d06", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.797585Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_980f855cfe084b41", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.798239Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_980f855cfe084b41", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.799954Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_ab3d57aa814f42aa", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.800626Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_ab3d57aa814f42aa", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.802149Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_881ae8d4c8434852", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.802807Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_881ae8d4c8434852", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.804609Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_a5619436472c417e", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.805230Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_a5619436472c417e", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.806870Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d1db933bee4344fb", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.807577Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d1db933bee4344fb", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.809434Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8d9b59ce0db34917", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.810024Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8d9b59ce0db34917", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.811566Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_b92416704b9e45c7", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.812345Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b92416704b9e45c7", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.814224Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_3e484232ff2f4ea3", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.815149Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_3e484232ff2f4ea3", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.816748Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_12be6e0d0b7a4491", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.817278Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_12be6e0d0b7a4491", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:03.924374Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_93fe914e64ca484c", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:03.925030Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_93fe914e64ca484c", "status_code": 200}
# INFO:     127.0.0.1:41666 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:04.080606Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_637f554e95754ec9", "method": "POST", "path": "/api/v1/ocr", "client": "127.0.0.1"}
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 0.50s
# {"timestamp": "2025-11-23T03:52:04.599606Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_637f554e95754ec9", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:04.600232Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_2358dd9d5aba464a", "method": "POST", "path": "/api/v1/detect-language", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41680 - "POST /api/v1/ocr HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:04.602013Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_3095c9cf2bc44899", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 0.51s
# {"timestamp": "2025-11-23T03:52:05.114760Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_2358dd9d5aba464a", "status_code": 200}
# INFO:nanonets.api:Request completed
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# POST     /api/v1/classify       2     0(0.00%) |  16022   15511   16534  16000 |    0.20        0.00
# GET      /api/v1/health      36     0(0.00%) |   1578       2   13563      4 |    2.20        0.00
# POST     /api/v1/ocr [small]       1     0(0.00%) |    522     522     522    522 |    0.00        0.00
# POST     /api/v1/ocr/batch       3     0(0.00%) |  14504   13385   15565  15000 |    0.30        0.00
# GET      /api/v1/ready       1     0(0.00%) |  13509   13509   13509  13509 |    0.10        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated      43     0(0.00%) |   3405       2   16534      4 |    2.80        0.00
#
# Processing page 1/1...
# Page 1 completed in 0.53s
# Processing page 1/1...
# Page 1 completed in 0.52s
# Processing page 1/1...
# Page 1 completed in 0.51s
# INFO:     127.0.0.1:41628 - "POST /api/v1/detect-language HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:06.690790Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_3095c9cf2bc44899", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:06.691837Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c5f1993b787a4e72", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:06.692096Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_f50817b2c3fb472e", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:06.692409Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c82b12e34eaf4a6f", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:06.692682Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_983a69d8289d4df8", "method": "POST", "path": "/api/v1/ocr", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:06.693104Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_259c3e1d2bb2453a", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# INFO:     127.0.0.1:35714 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:06.695913Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c5f1993b787a4e72", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:06.696052Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f50817b2c3fb472e", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:06.696361Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_259c3e1d2bb2453a", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41642 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# POST     /api/v1/classify       2     0(0.00%) |  16022   15511   16534  16000 |    0.20        0.00
# POST     /api/v1/detect-language       1     0(0.00%) |   2524    2524    2524   2524 |    0.00        0.00
# GET      /api/v1/health      38     0(0.00%) |   1549       2   13563      4 |    3.50        0.00
# POST     /api/v1/ocr [small]       1     0(0.00%) |    522     522     522    522 |    0.00        0.00
# POST     /api/v1/ocr/batch       4     0(0.00%) |  11510    2529   15565  13000 |    0.30        0.00
# GET      /api/v1/ready       1     0(0.00%) |  13509   13509   13509  13509 |    0.10        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated      47     0(0.00%) |   3266       2   16534      4 |    4.10        0.00
#
# Processing page 1/1...
# Page 1 completed in 0.52s
# Processing page 1/1...
# Page 1 completed in 0.53s
# Processing page 1/1...
# Page 1 completed in 0.54s
# Processing page 1/1...
# Page 1 completed in 0.50s
# {"timestamp": "2025-11-23T03:52:08.797983Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c82b12e34eaf4a6f", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:08.798167Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_983a69d8289d4df8", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:08.799018Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_72e5187c81d34cf0", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:08.799310Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6a2bb177311040b6", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:08.799612Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8f14c3ef06cc4f97", "method": "GET", "path": "/api/v1/ready", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41638 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41680 - "POST /api/v1/ocr HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:08.802183Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_72e5187c81d34cf0", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:08.802419Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6a2bb177311040b6", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:08.802592Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8f14c3ef06cc4f97", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41666 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41628 - "GET /api/v1/ready HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:08.805993Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_9997504011634ca8", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:08.806830Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_9997504011634ca8", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:08.808714Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c8ab380309aa4d61", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:08.809294Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c8ab380309aa4d61", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:08.810893Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_396c0a341f7f420f", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:08.811475Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_396c0a341f7f420f", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:08.813095Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_5f75075d63b74f5a", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:08.813771Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_5f75075d63b74f5a", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:08.815661Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_db0b5f64886643c8", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:08.816334Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_db0b5f64886643c8", "status_code": 200}
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# ...
# POST     /api/v1/detect-language       1     0(0.00%) |   2524    2524    2524   2524 |    0.00        0.00
# GET      /api/v1/health     129     0(0.00%) |    731       2   13563      4 |    2.20        0.00
# GET      /api/v1/metrics       1     0(0.00%) |   1379    1379    1379   1379 |    0.00        0.00
# GET      /api/v1/models       1     0(0.00%) |   1332    1332    1332   1332 |    0.10        0.00
# POST     /api/v1/ocr [large]       1     0(0.00%) |   4730    4730    4730   4730 |    0.00        0.00
# POST     /api/v1/ocr [medium]       1     0(0.00%) |   1801    1801    1801   1801 |    0.00        0.00
# POST     /api/v1/ocr [small]       2     0(0.00%) |   1563     522    2603    522 |    0.00        0.00
# POST     /api/v1/ocr/batch      13     0(0.00%) |   5010    1593   15565   2500 |    0.30        0.00
# GET      /api/v1/ready       2     0(0.00%) |   6954     398   13509    400 |    0.00        0.00
# POST     /api/v1/structured       1     0(0.00%) |   2556    2556    2556   2556 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated     158     0(0.00%) |   1456       2   16534      4 |    2.70        0.00
#
# Processing page 1/1...
# Page 1 completed in 0.47s
# Processing page 1/1...
# Page 1 completed in 0.48s
# Processing page 1/1...
# Page 1 completed in 0.51s
# {"timestamp": "2025-11-23T03:52:37.675878Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b1a59522167448cf", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:37.677233Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_7b8cf3b07bc144e1", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:37.677571Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_fd78201963654e13", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:37.677869Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_293629c3b1c04377", "method": "POST", "path": "/api/v1/ocr", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:37.678169Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_f4ca7c31cbff4419", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# INFO:     127.0.0.1:44526 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 1.65s
# {"timestamp": "2025-11-23T03:52:39.337977Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f401897d9d064de4", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:39.338154Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_7b8cf3b07bc144e1", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:39.338315Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_fd78201963654e13", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:39.338531Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f4ca7c31cbff4419", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:39.339437Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e9207aad8a2e42b4", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:39.339687Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_4026b431815e457b", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41628 - "POST /api/v1/structured HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41666 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41654 - "GET /api/v1/health HTTP/1.1" 200 OK
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# POST     /api/v1/classify       6     0(0.00%) |   6538     508   16534   1600 |    0.10        0.00
# POST     /api/v1/detect-language       1     0(0.00%) |   2524    2524    2524   2524 |    0.00        0.00
# GET      /api/v1/health     131     0(0.00%) |    768       2   13563      4 |    1.00        0.00
# GET      /api/v1/metrics       1     0(0.00%) |   1379    1379    1379   1379 |    0.00        0.00
# GET      /api/v1/models       1     0(0.00%) |   1332    1332    1332   1332 |    0.10        0.00
# POST     /api/v1/ocr [large]       1     0(0.00%) |   4730    4730    4730   4730 |    0.10        0.00
# POST     /api/v1/ocr [medium]       1     0(0.00%) |   1801    1801    1801   1801 |    0.00        0.00
# POST     /api/v1/ocr [small]       2     0(0.00%) |   1563     522    2603    522 |    0.00        0.00
# POST     /api/v1/ocr/batch      14     0(0.00%) |   5108    1593   15565   2500 |    0.20        0.00
# GET      /api/v1/ready       2     0(0.00%) |   6954     398   13509    400 |    0.00        0.00
# POST     /api/v1/structured       2     0(0.00%) |   3073    2556    3589   2600 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated     162     0(0.00%) |   1520       2   16534      4 |    1.50        0.00
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# Processing page 1/1...
# Page 1 completed in 0.46s
# {"timestamp": "2025-11-23T03:52:39.811962Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e9207aad8a2e42b4", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:39.812169Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_4026b431815e457b", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:39.812512Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_5fc451aa0462419b", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:39.814205Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_293629c3b1c04377", "status_code": 200}
# INFO:     127.0.0.1:41680 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41592 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:39.815940Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c251ca58723e4e66", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:39.816246Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_291c6a0cba094b0d", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41642 - "POST /api/v1/ocr HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:39.818736Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c251ca58723e4e66", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:39.818918Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_291c6a0cba094b0d", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# Processing page 1/1...
# Page 1 completed in 0.50s
# Processing page 1/1...
# Page 1 completed in 0.51s
# Processing page 1/1...
# Page 1 completed in 0.52s
# INFO:     127.0.0.1:41666 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:41.364566Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_5fc451aa0462419b", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:41.365531Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8bd5bf22c9b24f45", "method": "GET", "path": "/api/v1/metrics", "client": "127.0.0.1"}
# INFO:     127.0.0.1:44542 - "POST /api/v1/ocr/batch HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:41.367526Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8bd5bf22c9b24f45", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:41.367780Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_ab623c08a5004dad", "method": "POST", "path": "/api/v1/ocr/batch", "client": "127.0.0.1"}
# INFO:     127.0.0.1:41628 - "GET /api/v1/metrics HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:41.369588Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_dbcb21834b6e4436", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:41.370518Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8302979107224eae", "method": "GET", "path": "/api/v1/health", "client": "127.0.0.1"}
# {"timestamp": "2025-11-23T03:52:41.371747Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_dbcb21834b6e4436", "status_code": 200}
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# POST     /api/v1/classify       6     0(0.00%) |   6538     508   16534   1600 |    0.10        0.00
# POST     /api/v1/detect-language       1     0(0.00%) |   2524    2524    2524   2524 |    0.00        0.00
# GET      /api/v1/health     136     0(0.00%) |    816       2   13563      4 |    0.60        0.00
# GET      /api/v1/metrics       2     0(0.00%) |   1096     812    1379    812 |    0.00        0.00
# GET      /api/v1/models       1     0(0.00%) |   1332    1332    1332   1332 |    0.10        0.00
# POST     /api/v1/ocr [large]       1     0(0.00%) |   4730    4730    4730   4730 |    0.10        0.00
# POST     /api/v1/ocr [medium]       1     0(0.00%) |   1801    1801    1801   1801 |    0.00        0.00
# POST     /api/v1/ocr [small]       3     0(0.00%) |   2215     522    3519   2600 |    0.00        0.00
# POST     /api/v1/ocr/batch      15     0(0.00%) |   4990    1593   15565   2700 |    0.20        0.00
# GET      /api/v1/ready       2     0(0.00%) |   6954     398   13509    400 |    0.00        0.00
# POST     /api/v1/structured       2     0(0.00%) |   3073    2556    3589   2600 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated     170     0(0.00%) |   1555       2   16534      4 |    1.10        0.00
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# [2025-11-23 03:52:42,571] 1544c18f1fe6/INFO/locust.main: --run-time limit reached, shutting down
# Load test completed.
# [2025-11-23 03:52:42,627] 1544c18f1fe6/INFO/locust.main: Shutting down (exit code 0)
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# POST     /api/v1/classify       6     0(0.00%) |   6538     508   16534   1600 |    0.10        0.00
# POST     /api/v1/detect-language       1     0(0.00%) |   2524    2524    2524   2524 |    0.02        0.00
# GET      /api/v1/health     136     0(0.00%) |    816       2   13563      4 |    2.34        0.00
# GET      /api/v1/metrics       2     0(0.00%) |   1096     812    1379    812 |    0.03        0.00
# GET      /api/v1/models       1     0(0.00%) |   1332    1332    1332   1332 |    0.02        0.00
# POST     /api/v1/ocr [large]       1     0(0.00%) |   4730    4730    4730   4730 |    0.02        0.00
# POST     /api/v1/ocr [medium]       1     0(0.00%) |   1801    1801    1801   1801 |    0.02        0.00
# POST     /api/v1/ocr [small]       3     0(0.00%) |   2215     522    3519   2600 |    0.05        0.00
# POST     /api/v1/ocr/batch      15     0(0.00%) |   4990    1593   15565   2700 |    0.26        0.00
# GET      /api/v1/ready       2     0(0.00%) |   6954     398   13509    400 |    0.03        0.00
# POST     /api/v1/structured       2     0(0.00%) |   3073    2556    3589   2600 |    0.03        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated     170     0(0.00%) |   1555       2   16534      4 |    2.93        0.00
#
# Response time percentiles (approximated)
# Type     Name      50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------||--------|------|------|------|------|------|------|------|------|------|------|------
# POST     /api/v1/classify     3600   3600  16000  16000  17000  17000  17000  17000  17000  17000  17000      6
# POST     /api/v1/detect-language     2500   2500   2500   2500   2500   2500   2500   2500   2500   2500   2500      1
# GET      /api/v1/health        4      5    610    960   2000   4200  13000  13000  14000  14000  14000    136
# GET      /api/v1/metrics     1400   1400   1400   1400   1400   1400   1400   1400   1400   1400   1400      2
# GET      /api/v1/models     1300   1300   1300   1300   1300   1300   1300   1300   1300   1300   1300      1
# POST     /api/v1/ocr [large]     4700   4700   4700   4700   4700   4700   4700   4700   4700   4700   4700      1
# POST     /api/v1/ocr [medium]     1800   1800   1800   1800   1800   1800   1800   1800   1800   1800   1800      1
# POST     /api/v1/ocr [small]     2600   2600   3500   3500   3500   3500   3500   3500   3500   3500   3500      3
# POST     /api/v1/ocr/batch     2700   3000   6400  13000  15000  16000  16000  16000  16000  16000  16000     15
# GET      /api/v1/ready    14000  14000  14000  14000  14000  14000  14000  14000  14000  14000  14000      2
# POST     /api/v1/structured     3600   3600   3600   3600   3600   3600   3600   3600   3600   3600   3600      2
# --------||--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated        4    960   1600   2000   3600  13000  15000  16000  17000  17000  17000    170

# %%
# ============================================
# CELL 14: CONCURRENT LOAD TEST
# ============================================
print("=" * 60)
print("CONCURRENT LOAD TEST")
print("=" * 60)

import time
from concurrent.futures import ThreadPoolExecutor
from fastapi.testclient import TestClient
import logging

# Suppress verbose logs
logging.getLogger("nanonets.api").setLevel(logging.WARNING)

from api.server import app
client = TestClient(app)

def make_request():
    return client.get("/api/v1/health").status_code

# Run test
start = time.time()
with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(executor.map(lambda _: make_request(), range(100)))

elapsed = time.time() - start

print(f"\n=== LOAD TEST RESULTS ===")
print(f"Total requests: 100")
print(f"Success: {results.count(200)}")
print(f"Failed: {len(results) - results.count(200)}")
print(f"Time: {elapsed:.2f}s")
print(f"Throughput: {100/elapsed:.1f} req/s")
print("")
# Out:
# ============================================================
# CONCURRENT LOAD TEST
# ============================================================
# Processing page 1/1...
# Page 1 completed in 0.52s
# Processing page 1/1...
# Page 1 completed in 0.53s
# Processing page 1/1...
# Page 1 completed in 0.55s
# {"timestamp": "2025-11-23T03:52:42.975822Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8302979107224eae", "status_code": 200}
# INFO:     127.0.0.1:41666 - "GET /api/v1/health HTTP/1.1" 200 OK
# {"timestamp": "2025-11-23T03:52:42.976915Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_ab623c08a5004dad", "status_code": 200}
# INFO:     127.0.0.1:41620 - "GET /api/v1/health HTTP/1.1" 200 OK
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [485]
# 2025-11-23 03:52:49.134104: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763869969.158747      71 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763869969.166535      71 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# WARNING:passlib.handlers.bcrypt:(trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/passlib/handlers/bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# {"timestamp": "2025-11-23T03:52:55.472459Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d60e635b2d264cdb", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.480425Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_62571cf551864a71", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.485062Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d6705796467545ba", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.486402Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_2d453869a7154975", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.488167Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_fc8b243e657043a2", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.489250Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_88b6f60b37c74f43", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.491646Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_83b4d6ca6c6a48c7", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.493478Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d60e635b2d264cdb", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.495364Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_0fb71c062b724744", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.497205Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_96c4e467b06a42dd", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.500289Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_2e1fe34940444b32", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.501163Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_62571cf551864a71", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.503087Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d6705796467545ba", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.506905Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_2d453869a7154975", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.508947Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_fc8b243e657043a2", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.510989Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_88b6f60b37c74f43", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.513160Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_83b4d6ca6c6a48c7", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.517917Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_0fb71c062b724744", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.520583Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_96c4e467b06a42dd", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.528956Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_3f543322ac32436f", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.532780Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_2e1fe34940444b32", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.544803Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_7086c998be7d4ea6", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.548078Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_69581c3efafe4d77", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.549380Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d8a9cb010c00422b", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.553081Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_05c414fe10f34d9f", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.558084Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_01cbb8e30f944aac", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.559273Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_897da644bd2440b7", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.561479Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_3f543322ac32436f", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.563061Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e0c2754dc9804e1f", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.565419Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8697e3bfc80c4c04", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.567236Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_7086c998be7d4ea6", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.568680Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_69581c3efafe4d77", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.570282Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_9c4dc85cd6b44544", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.574400Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d8a9cb010c00422b", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.576239Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_05c414fe10f34d9f", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.579037Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_01cbb8e30f944aac", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.582644Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_897da644bd2440b7", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.584060Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e0c2754dc9804e1f", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.587236Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8697e3bfc80c4c04", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.591109Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_cf936b5bccfc4e62", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.594356Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_9c4dc85cd6b44544", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.597910Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_dd76b8a58efb46c7", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.601752Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6b2f6b973f354d0d", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.609002Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_acd517d54b784880", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.614055Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_cb48002c61624aa4", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.615132Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_cf936b5bccfc4e62", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.616780Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6c9c3c2a49a1452e", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.619361Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c21c2f15d9b44cdc", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.621608Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_9b6886296a634016", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.633100Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_dd76b8a58efb46c7", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.635736Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_9103edea5f1644be", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.637434Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6b2f6b973f354d0d", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.638724Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_f20aecec5eb246a4", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.642083Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_acd517d54b784880", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.647547Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_cb48002c61624aa4", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.649848Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6c9c3c2a49a1452e", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.651241Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c21c2f15d9b44cdc", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.652787Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_9b6886296a634016", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.655273Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6002c6db97834b07", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.658914Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_9103edea5f1644be", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.662436Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_a3e6f27b93a048b6", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.663194Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f20aecec5eb246a4", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.675353Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_33f91847755444b8", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.686011Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_82e7018af4c44fdb", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.690278Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6002c6db97834b07", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.693829Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c097e74294d540fb", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.698392Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_447e0c022d8b4a34", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.700406Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e0e7a0cdf0f14c14", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.703523Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_a3e6f27b93a048b6", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.707675Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c4d6aa68751441c8", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.709063Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_33f91847755444b8", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.712526Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6101a0cd1c2e40c6", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.715797Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_82e7018af4c44fdb", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.719578Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d26c764b373b4304", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.721326Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c097e74294d540fb", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.722295Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_447e0c022d8b4a34", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.725659Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e0e7a0cdf0f14c14", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.727050Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_5929e30aa5ad4fe3", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.730742Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c4d6aa68751441c8", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.732395Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_3b2bd7d5fb2a4ae3", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.736351Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6101a0cd1c2e40c6", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.738535Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_2e0df2f82b644be3", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.741325Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d26c764b373b4304", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.744813Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_44dbe5840a2e40c8", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.747888Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_5929e30aa5ad4fe3", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.751598Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_d3ef92e6dbd84764", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.754829Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_3b2bd7d5fb2a4ae3", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.769041Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_7975b172ac644ba7", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.769987Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_37ecec5322c24b6e", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.774563Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_2e0df2f82b644be3", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.777999Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_a0a0b5daeb4845b3", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.780966Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_44dbe5840a2e40c8", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.784291Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8d628bf2f9784225", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.788324Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_4ce3de00366b42c8", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.790881Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_d3ef92e6dbd84764", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.796574Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_61f093fd90084e20", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.797807Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_7975b172ac644ba7", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.802165Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_37ecec5322c24b6e", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.805909Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_918d09cd27984f53", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.809015Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_a0a0b5daeb4845b3", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.811372Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_2e885f0c03f04377", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.814910Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8d628bf2f9784225", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.817141Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_4ce3de00366b42c8", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.820624Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_61f093fd90084e20", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.824689Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_4f7dc09eeac3480f", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.828343Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_35f20807a9514cd7", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.830026Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_918d09cd27984f53", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.832909Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_1336e255c54347a4", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.836807Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e98b46514e4b470b", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.839268Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_2e885f0c03f04377", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.843476Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_17afb9ddaa404896", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.847708Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_4f7dc09eeac3480f", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.850153Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6eff80c95d2f444c", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.854261Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_35f20807a9514cd7", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.856250Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_146f987f14e94a5d", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.858353Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_1336e255c54347a4", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.863892Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_34c0845ad5d8410a", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.866999Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e98b46514e4b470b", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.872272Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_0da423e246004af2", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.877291Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_17afb9ddaa404896", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.892486Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6eff80c95d2f444c", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.895290Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_146f987f14e94a5d", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.901782Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8083016a5ea64148", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.904607Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_9edf5bbf9c524cec", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.907932Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_bc2e0aacbd6c4955", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.910838Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_34c0845ad5d8410a", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.912506Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_0da423e246004af2", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.914341Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_38aa6a4a889a4bd2", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.916088Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_b9f34db8ccec433a", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.922383Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8b63ba9413004d26", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.925556Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8083016a5ea64148", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.926410Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_b51ac220c1114b2a", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.928632Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_348ac422cb394c6f", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.931667Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_9edf5bbf9c524cec", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.934152Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_bc2e0aacbd6c4955", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.938292Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_dafd38a1c5f44127", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.940585Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_38aa6a4a889a4bd2", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.942393Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_9abafa18a0ce4001", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.946234Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b9f34db8ccec433a", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.949105Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8b63ba9413004d26", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.951047Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b51ac220c1114b2a", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.953941Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_348ac422cb394c6f", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.957359Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_8b6d153ce3a94dde", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.959131Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_dafd38a1c5f44127", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.961708Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_f6bb93fc91444d37", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.967852Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_b76d7295004245e3", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.970465Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_9abafa18a0ce4001", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.975079Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_bb37ee6fdecd4dfd", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.977136Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_41b1873d7a474f9e", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.978709Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_2c8a4a3d6fe04419", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.982016Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_8b6d153ce3a94dde", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:55.985042Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f6bb93fc91444d37", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.987063Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c8a73088567a470b", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.989084Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_b5a8d7f43a6e45b3", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.990377Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_9907055226f040de", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:55.991900Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b76d7295004245e3", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:55.993052Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_bb37ee6fdecd4dfd", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.997002Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_41b1873d7a474f9e", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:55.999451Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_1869d118bbc548b5", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.001717Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_2c8a4a3d6fe04419", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:56.003712Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c8a73088567a470b", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:56.011234Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_b5a8d7f43a6e45b3", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:56.012541Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_9907055226f040de", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.013518Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c044c7a9c36f4b25", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.016189Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_7396561960d547cb", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.030181Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e6e4bbe762724550", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:56.031909Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_1869d118bbc548b5", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.034581Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_eac1e1fe5cae43aa", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.040272Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_6a47630765c64973", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.050250Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_14d30b1c7a2f4a08", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.053793Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c044c7a9c36f4b25", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.057199Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_5bd5490ac55b41b0", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:56.058231Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_953e9bcdc3584747", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.063536Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_7396561960d547cb", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.065202Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_86d7c1dc7dae4483", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.066573Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e6e4bbe762724550", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.069557Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_eac1e1fe5cae43aa", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:56.075487Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_6a47630765c64973", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.076644Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_f31afe953bb64574", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.079743Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_14d30b1c7a2f4a08", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.082019Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_5bd5490ac55b41b0", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:56.084715Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_953e9bcdc3584747", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.086325Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_61a022c9b7044cf4", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:56.089076Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_86d7c1dc7dae4483", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.092579Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_a8bb6717920e4e9f", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.098809Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_f31afe953bb64574", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.100510Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c657dd65edd5432a", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.108170Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_47d70887e1694828", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:56.109921Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_61a022c9b7044cf4", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.113622Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_94e978ced0864e23", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.119255Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e1c05030c8384531", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:56.122469Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_a8bb6717920e4e9f", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.126564Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_e5ad1903a96f4175", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.127798Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_c38abb696f924710", "method": "GET", "path": "/api/v1/health", "client": "testclient"}
# {"timestamp": "2025-11-23T03:52:56.129236Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c657dd65edd5432a", "status_code": 200}
# INFO:nanonets.api:Request started
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.131856Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_47d70887e1694828", "status_code": 200}
# {"timestamp": "2025-11-23T03:52:56.133367Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_94e978ced0864e23", "status_code": 200}
# INFO:nanonets.api:Request completed
# {"timestamp": "2025-11-23T03:52:56.135367Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e1c05030c8384531", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.137703Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_e5ad1903a96f4175", "status_code": 200}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.139548Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_c38abb696f924710", "status_code": 200}
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# INFO:nanonets.api:Request completed
# === LOAD TEST RESULTS ===
# Total requests: 100
# Success: 100
# Failed: 0
# Time: 0.70s
# Throughput: 142.0 req/s

# %%
# ============================================
# CELL 15: ROUTE VERIFICATION
# ============================================
print("=" * 60)
print("AVAILABLE API ROUTES")
print("=" * 60)

response = client.get("/openapi.json")
for path in sorted(response.json()["paths"]):
    print(f"  {path}")
print("")
# Out:
# ============================================================
# AVAILABLE API ROUTES
# ============================================================
# {"timestamp": "2025-11-23T03:52:56.167475Z", "level": "INFO", "logger": "nanonets.api", "message": "Request started", "module": "", "function": null, "line": 0, "request_id": "req_7d03a2dcf24c4f88", "method": "GET", "path": "/openapi.json", "client": "testclient"}
# INFO:nanonets.api:Request started
# {"timestamp": "2025-11-23T03:52:56.192847Z", "level": "INFO", "logger": "nanonets.api", "message": "Request completed", "module": "", "function": null, "line": 0, "request_id": "req_7d03a2dcf24c4f88", "status_code": 200}
# INFO:nanonets.api:Request completed
#   /
#   /api/v1/auth/api-keys
#   /api/v1/auth/api-keys/{key_id}
#   /api/v1/auth/login
#   /api/v1/auth/me
#   /api/v1/auth/refresh
#   /api/v1/auth/register
#   /api/v1/classify
#   /api/v1/detect-language
#   /api/v1/extract-entities
#   /api/v1/health
#   /api/v1/live
#   /api/v1/metrics
#   /api/v1/metrics/json
#   /api/v1/models
#   /api/v1/ocr
#   /api/v1/ocr/batch
#   /api/v1/ocr/{job_id}
#   /api/v1/ready
#   /api/v1/structured
#   /api/v1/v2/ocr
#   /api/v1/webhooks
#   /api/v1/webhooks/register
#   /api/v1/webhooks/{webhook_id}
#   /api/v1/webhooks/{webhook_id}/history

# %%
# ============================================
# CELL 16: TEST SUMMARY
# ============================================
print("=" * 60)
print("✓ ALL TESTS COMPLETED")
print("=" * 60)
print("""
Test Categories:
  ✓ Syntax check
  ✓ Core module tests
  ✓ Services tests
  ✓ Utils tests
  ✓ API tests
  ✓ Asset-based tests
  ✓ Unit tests (pytest)
  ✓ Integration tests (pytest)
  ✓ Full test suite with coverage
  ✓ Benchmark tests
  ✓ API endpoint tests (curl)
  ✓ Load tests (locust)
  ✓ Concurrent load test
""")
# Out:
# ============================================================
# ✓ ALL TESTS COMPLETED
# ============================================================
#
# Test Categories:
#   ✓ Syntax check
#   ✓ Core module tests
#   ✓ Services tests
#   ✓ Utils tests
#   ✓ API tests
#   ✓ Asset-based tests
#   ✓ Unit tests (pytest)
#   ✓ Integration tests (pytest)
#   ✓ Full test suite with coverage
#   ✓ Benchmark tests
#   ✓ API endpoint tests (curl)
#   ✓ Load tests (locust)
#   ✓ Concurrent load test

# %%
# ============================================
# CELL 17: RUN GRADIO UI (OPTIONAL)
# ============================================
# Uncomment to run UI with public share URL
# !UI_SHARE=true python run_ui.py
# Out:
# ============================================================
# NANONETS OCR - GRADIO UI
# ============================================================
#
# [1/3] Initializing OCR engine...
# 2025-11-23 03:54:29.119030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763870069.144044     637 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763870069.151391     637 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Loading model: nanonets/Nanonets-OCR-s
# [cuda] Loading model: nanonets/Nanonets-OCR-s
# [cuda] CUDA available. Loading with optimizations.
# `torch_dtype` is deprecated! Use `dtype` instead!
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# [cuda] Warning: Optimized loading failed: Using `bitsandbytes` 8-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes`
# Fetching 2 files: 100%|████████████████████████| 2/2 [00:00<00:00, 24600.02it/s]
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:07<00:00,  3.94s/it]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# Model and processor loaded successfully
#   ✓ Model loaded successfully
#
# [2/3] Creating Gradio interface...
#   ✓ Interface created
#
# [3/3] Launching server...
#
#   Host: 0.0.0.0
#   Port: 7860
#   Share: True
# ============================================================
#
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://a2154ad437fc7aada3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Processing page 1/1...
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Page 1 completed in 157.36s
